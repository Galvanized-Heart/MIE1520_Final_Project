# %%
from tools.utils import *
from tools.hom_networks import *

import torch

from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader

from sklearn.model_selection import train_test_split

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random
seed = 42

# Model
hidden_channels = 128
num_classes = 6
num_layers = 2
aggr='mean'
dropout = 0.5 # Validated choice in experiment 2

# Training
batch_size = 32
epochs = 30
lr = 1e-4
maxlr = 3e-4

# %% [markdown]
# # Preprocess

# %%
# Load the ENZYMES dataset
hom_dataset = TUDataset(root='data', name='ENZYMES')                          # This has 3 one-hot encodings
hom_dataset_attr = TUDataset(root='data', name='ENZYMES', use_node_attr=True) # This has 3 one-hot encodings and 18 features

# %%
def normalize_enzymes_data(data):
    data = data.clone()
    if hasattr(data, 'x') and data.x is not None:
        x = data.x
        feats = x[:, :18]
        mean = feats.mean(dim=0)
        std = feats.std(dim=0, unbiased=False)
        std[std == 0] = 1.0
        normalized_feats = (feats - mean) / std
        x[:, :18] = normalized_feats
        data.x = x
    return data

# Normalize features
normalized_hom_dataset_attr = [normalize_enzymes_data(hom_data) for hom_data in hom_dataset_attr]

# %%
# Create splits
labels = [data.y.item() for data in normalized_hom_dataset_attr]

train_set, temp_set = train_test_split(
    normalized_hom_dataset_attr, 
    test_size=0.3, 
    stratify=labels,
    random_state=seed
    
)

temp_labels = [data.y.item() for data in temp_set]
valid_set, test_set = train_test_split(
    temp_set, 
    test_size=0.5, 
    stratify=temp_labels,
    random_state=seed
)

# train_loader is defined at each experiment for reproducibility
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Weight decay 1e-4 GraphConv

# %%
decay = 1e-4

# %%
experiment_name = f"ENZYMES-HomoGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{aggr} aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-{decay} decay-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HomoGNN_GraphConv(hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, aggr=aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HomoGNN_GraphConv(
#   (node_emb_layers): ModuleList(
#     (0): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): GraphConv((-1, -1), 128)
#       (post_lin): MLP(
#         (layers): ModuleList(
#           (0): Linear(-1, 128, bias=True)
#           (1): Dropout(p=0.5, inplace=False)
#           (2): Linear(128, 128, bias=True)
#         )
#       )
#     )
#   )
#   (classifier): Linear(128, 6, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, hom_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, hom_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7934 | Validation Loss: 1.7934
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0800 | Validation F1: 0.0476
#
# Epoch 2/30
# Train Loss: 1.7935 | Validation Loss: 1.7933
# Train Acc: 0.1619 | Validation Acc: 0.1667
# Train F1: 0.0754 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7932 | Validation Loss: 1.7932
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0774 | Validation F1: 0.0476
#
# Epoch 4/30
# Train Loss: 1.7933 | Validation Loss: 1.7931
# Train Acc: 0.1619 | Validation Acc: 0.1667
# Train F1: 0.0679 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7932 | Validation Loss: 1.7930
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.0821 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7929 | Validation Loss: 1.7928
# Train Acc: 0.1571 | Validation Acc: 0.1667
# Train F1: 0.0732 | Validation F1: 0.0476
#
# Epoch 7/30
# Train Loss: 1.7931 | Validation Loss: 1.7929
# Train Acc: 0.1833 | Validation Acc: 0.1667
# Train F1: 0.0917 | Validation F1: 0.0476
#
# Epoch 8/30
# Train Loss: 1.7929 | Validation Loss: 1.7928
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.0639 | Validation F1: 0.0476
#
# Epoch 9/30
# Train Loss: 1.7929 | Validation Loss: 1.7923
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 10/30
# Train Loss: 1.7923 | Validation Loss: 1.7921
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0710 | Validation F1: 0.0476
#
# Epoch 11/30
# Train Loss: 1.7915 | Validation Loss: 1.7919
# Train Acc: 0.1929 | Validation Acc: 0.1778
# Train F1: 0.1013 | Validation F1: 0.0779
#
# Epoch 12/30
# Train Loss: 1.7917 | Validation Loss: 1.7911
# Train Acc: 0.1786 | Validation Acc: 0.1889
# Train F1: 0.1146 | Validation F1: 0.0861
#
# Epoch 13/30
# Train Loss: 1.7904 | Validation Loss: 1.7895
# Train Acc: 0.1952 | Validation Acc: 0.1778
# Train F1: 0.1048 | Validation F1: 0.0682
#
# Epoch 14/30
# Train Loss: 1.7875 | Validation Loss: 1.7878
# Train Acc: 0.1690 | Validation Acc: 0.2222
# Train F1: 0.1579 | Validation F1: 0.1426
#
# Epoch 15/30
# Train Loss: 1.7874 | Validation Loss: 1.7897
# Train Acc: 0.1905 | Validation Acc: 0.1667
# Train F1: 0.1268 | Validation F1: 0.0476
#
# Epoch 16/30
# Train Loss: 1.7873 | Validation Loss: 1.7855
# Train Acc: 0.1619 | Validation Acc: 0.2556
# Train F1: 0.0555 | Validation F1: 0.1302
#
# Epoch 17/30
# Train Loss: 1.7807 | Validation Loss: 1.7848
# Train Acc: 0.2024 | Validation Acc: 0.1889
# Train F1: 0.1740 | Validation F1: 0.0865
#
# Epoch 18/30
# Train Loss: 1.7761 | Validation Loss: 1.7791
# Train Acc: 0.2071 | Validation Acc: 0.1889
# Train F1: 0.1186 | Validation F1: 0.0861
#
# Epoch 19/30
# Train Loss: 1.7630 | Validation Loss: 1.7636
# Train Acc: 0.2333 | Validation Acc: 0.2778
# Train F1: 0.1669 | Validation F1: 0.1936
#
# Epoch 20/30
# Train Loss: 1.7430 | Validation Loss: 1.7531
# Train Acc: 0.2310 | Validation Acc: 0.2444
# Train F1: 0.1645 | Validation F1: 0.1688
#
# Epoch 21/30
# Train Loss: 1.7241 | Validation Loss: 1.7536
# Train Acc: 0.2262 | Validation Acc: 0.2556
# Train F1: 0.1609 | Validation F1: 0.1758
#
# Epoch 22/30
# Train Loss: 1.7210 | Validation Loss: 1.7484
# Train Acc: 0.2238 | Validation Acc: 0.2778
# Train F1: 0.1783 | Validation F1: 0.2281
#
# Epoch 23/30
# Train Loss: 1.7165 | Validation Loss: 1.7444
# Train Acc: 0.2357 | Validation Acc: 0.2778
# Train F1: 0.1955 | Validation F1: 0.1982
#
# Epoch 24/30
# Train Loss: 1.7121 | Validation Loss: 1.7435
# Train Acc: 0.2381 | Validation Acc: 0.3000
# Train F1: 0.1869 | Validation F1: 0.2053
#
# Epoch 25/30
# Train Loss: 1.7118 | Validation Loss: 1.7486
# Train Acc: 0.2524 | Validation Acc: 0.2333
# Train F1: 0.2083 | Validation F1: 0.1623
#
# Epoch 26/30
# Train Loss: 1.7087 | Validation Loss: 1.7427
# Train Acc: 0.2476 | Validation Acc: 0.2889
# Train F1: 0.2058 | Validation F1: 0.2296
#
# Epoch 27/30
# Train Loss: 1.6947 | Validation Loss: 1.7424
# Train Acc: 0.2500 | Validation Acc: 0.3000
# Train F1: 0.2120 | Validation F1: 0.2351
#
# Epoch 28/30
# Train Loss: 1.7035 | Validation Loss: 1.7431
# Train Acc: 0.2643 | Validation Acc: 0.2889
# Train F1: 0.2333 | Validation F1: 0.2323
#
# Epoch 29/30
# Train Loss: 1.7051 | Validation Loss: 1.7429
# Train Acc: 0.2524 | Validation Acc: 0.2889
# Train F1: 0.2165 | Validation F1: 0.2323
#
# Epoch 30/30
# Train Loss: 1.7061 | Validation Loss: 1.7429
# Train Acc: 0.2619 | Validation Acc: 0.2889
# Train F1: 0.2308 | Validation F1: 0.2328

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_88150_row0_col0, #T_88150_row0_col4, #T_88150_row0_col6, #T_88150_row1_col4, #T_88150_row1_col6, #T_88150_row2_col4, #T_88150_row2_col6, #T_88150_row3_col4, #T_88150_row3_col6, #T_88150_row4_col4, #T_88150_row4_col6, #T_88150_row5_col3, #T_88150_row5_col4, #T_88150_row5_col6, #T_88150_row6_col4, #T_88150_row6_col6, #T_88150_row7_col4, #T_88150_row7_col6, #T_88150_row8_col4, #T_88150_row8_col5, #T_88150_row8_col6, #T_88150_row9_col4, #T_88150_row9_col6, #T_88150_row14_col4, #T_88150_row14_col6, #T_88150_row26_col1, #T_88150_row26_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_88150_row0_col1, #T_88150_row0_col2, #T_88150_row1_col1, #T_88150_row1_col2, #T_88150_row2_col1, #T_88150_row2_col2, #T_88150_row3_col1, #T_88150_row4_col1, #T_88150_row23_col4, #T_88150_row26_col4, #T_88150_row26_col6, #T_88150_row27_col3, #T_88150_row27_col5, #T_88150_row29_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_88150_row0_col3, #T_88150_row3_col5, #T_88150_row9_col3, #T_88150_row12_col6, #T_88150_row13_col3 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_88150_row0_col5, #T_88150_row5_col0, #T_88150_row23_col1, #T_88150_row24_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_88150_row1_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_88150_row1_col3, #T_88150_row3_col3, #T_88150_row15_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_88150_row1_col5 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_88150_row2_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_88150_row2_col3, #T_88150_row7_col5, #T_88150_row8_col3, #T_88150_row27_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_88150_row2_col5, #T_88150_row10_col6 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_88150_row3_col0, #T_88150_row28_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_88150_row3_col2, #T_88150_row4_col2, #T_88150_row5_col1, #T_88150_row6_col1, #T_88150_row7_col1, #T_88150_row8_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_88150_row4_col0, #T_88150_row5_col5 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_88150_row4_col3, #T_88150_row20_col2, #T_88150_row22_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_88150_row4_col5 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_88150_row5_col2, #T_88150_row6_col2, #T_88150_row7_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_88150_row6_col0, #T_88150_row11_col6, #T_88150_row17_col6 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_88150_row6_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_88150_row6_col5 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_88150_row7_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_88150_row7_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_88150_row8_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_88150_row8_col2, #T_88150_row10_col1, #T_88150_row29_col3 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_88150_row9_col0, #T_88150_row14_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_88150_row9_col1, #T_88150_row27_col6, #T_88150_row28_col6, #T_88150_row29_col5, #T_88150_row29_col6 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_88150_row9_col2 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_88150_row9_col5 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_88150_row10_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_88150_row10_col2, #T_88150_row25_col6 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_88150_row10_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_88150_row10_col4, #T_88150_row12_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_88150_row10_col5 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_88150_row11_col0, #T_88150_row17_col5 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_88150_row11_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_88150_row11_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_88150_row11_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_88150_row11_col4, #T_88150_row16_col4, #T_88150_row17_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_88150_row11_col5 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_88150_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_88150_row12_col1, #T_88150_row28_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_88150_row12_col2 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_88150_row12_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_88150_row12_col5 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_88150_row13_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_88150_row13_col1, #T_88150_row14_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_88150_row13_col2, #T_88150_row24_col3, #T_88150_row28_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_88150_row13_col4, #T_88150_row18_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_88150_row13_col5 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_88150_row13_col6 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_88150_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_88150_row14_col2 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_88150_row14_col5 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_88150_row15_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_88150_row15_col1 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_88150_row15_col2, #T_88150_row25_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_88150_row15_col4, #T_88150_row20_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_88150_row15_col5, #T_88150_row22_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_88150_row15_col6 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_88150_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_88150_row16_col1 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_88150_row16_col2, #T_88150_row18_col4, #T_88150_row21_col4, #T_88150_row22_col4 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_88150_row16_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_88150_row16_col5, #T_88150_row20_col6 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_88150_row16_col6, #T_88150_row19_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_88150_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_88150_row17_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_88150_row17_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_88150_row17_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_88150_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_88150_row18_col1, #T_88150_row19_col3, #T_88150_row20_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_88150_row18_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_88150_row18_col5, #T_88150_row20_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_88150_row18_col6 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_88150_row19_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_88150_row19_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_88150_row19_col4 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_88150_row19_col5 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_88150_row19_col6 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_88150_row20_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_88150_row20_col5, #T_88150_row24_col6 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_88150_row21_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_88150_row21_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_88150_row21_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_88150_row21_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_88150_row21_col5 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_88150_row21_col6 {
#   background-co

# %% [markdown]
# # Weight decay 5e-4 GraphConv

# %%
decay = 5e-4

# %%
experiment_name = f"ENZYMES-HomoGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{aggr} aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-{decay} decay-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HomoGNN_GraphConv(hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, aggr=aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HomoGNN_GraphConv(
#   (node_emb_layers): ModuleList(
#     (0): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): GraphConv((-1, -1), 128)
#       (post_lin): MLP(
#         (layers): ModuleList(
#           (0): Linear(-1, 128, bias=True)
#           (1): Dropout(p=0.5, inplace=False)
#           (2): Linear(128, 128, bias=True)
#         )
#       )
#     )
#   )
#   (classifier): Linear(128, 6, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, hom_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, hom_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7934 | Validation Loss: 1.7934
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0800 | Validation F1: 0.0476
#
# Epoch 2/30
# Train Loss: 1.7935 | Validation Loss: 1.7933
# Train Acc: 0.1643 | Validation Acc: 0.1667
# Train F1: 0.0763 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7932 | Validation Loss: 1.7932
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0778 | Validation F1: 0.0476
#
# Epoch 4/30
# Train Loss: 1.7933 | Validation Loss: 1.7931
# Train Acc: 0.1619 | Validation Acc: 0.1667
# Train F1: 0.0679 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7932 | Validation Loss: 1.7930
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.0828 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7929 | Validation Loss: 1.7929
# Train Acc: 0.1595 | Validation Acc: 0.1667
# Train F1: 0.0715 | Validation F1: 0.0476
#
# Epoch 7/30
# Train Loss: 1.7932 | Validation Loss: 1.7930
# Train Acc: 0.1786 | Validation Acc: 0.1667
# Train F1: 0.0871 | Validation F1: 0.0476
#
# Epoch 8/30
# Train Loss: 1.7930 | Validation Loss: 1.7930
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.0640 | Validation F1: 0.0476
#
# Epoch 9/30
# Train Loss: 1.7931 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 10/30
# Train Loss: 1.7929 | Validation Loss: 1.7926
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0563 | Validation F1: 0.0476
#
# Epoch 11/30
# Train Loss: 1.7921 | Validation Loss: 1.7925
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.0894 | Validation F1: 0.0476
#
# Epoch 12/30
# Train Loss: 1.7929 | Validation Loss: 1.7925
# Train Acc: 0.1357 | Validation Acc: 0.1667
# Train F1: 0.0845 | Validation F1: 0.0476
#
# Epoch 13/30
# Train Loss: 1.7927 | Validation Loss: 1.7923
# Train Acc: 0.1500 | Validation Acc: 0.1667
# Train F1: 0.0763 | Validation F1: 0.0476
#
# Epoch 14/30
# Train Loss: 1.7923 | Validation Loss: 1.7922
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.0836 | Validation F1: 0.0476
#
# Epoch 15/30
# Train Loss: 1.7919 | Validation Loss: 1.7922
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0567 | Validation F1: 0.0476
#
# Epoch 16/30
# Train Loss: 1.7925 | Validation Loss: 1.7924
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 17/30
# Train Loss: 1.7921 | Validation Loss: 1.7922
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 18/30
# Train Loss: 1.7920 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 19/30
# Train Loss: 1.7915 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 20/30
# Train Loss: 1.7923 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 21/30
# Train Loss: 1.7920 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 22/30
# Train Loss: 1.7926 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 23/30
# Train Loss: 1.7925 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 24/30
# Train Loss: 1.7926 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 25/30
# Train Loss: 1.7916 | Validation Loss: 1.7919
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0479 | Validation F1: 0.0476
#
# Epoch 26/30
# Train Loss: 1.7918 | Validation Loss: 1.7919
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0478 | Validation F1: 0.0476
#
# Epoch 27/30
# Train Loss: 1.7916 | Validation Loss: 1.7919
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 28/30
# Train Loss: 1.7916 | Validation Loss: 1.7919
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0524 | Validation F1: 0.0476
#
# Epoch 29/30
# Train Loss: 1.7917 | Validation Loss: 1.7919
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 30/30
# Train Loss: 1.7918 | Validation Loss: 1.7919
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_d55ed_row0_col0, #T_d55ed_row0_col4, #T_d55ed_row0_col6, #T_d55ed_row1_col4, #T_d55ed_row1_col6, #T_d55ed_row2_col4, #T_d55ed_row2_col6, #T_d55ed_row3_col4, #T_d55ed_row3_col6, #T_d55ed_row4_col4, #T_d55ed_row4_col6, #T_d55ed_row5_col4, #T_d55ed_row5_col6, #T_d55ed_row6_col4, #T_d55ed_row6_col6, #T_d55ed_row7_col4, #T_d55ed_row7_col6, #T_d55ed_row8_col4, #T_d55ed_row8_col5, #T_d55ed_row8_col6, #T_d55ed_row9_col4, #T_d55ed_row9_col6, #T_d55ed_row10_col4, #T_d55ed_row10_col6, #T_d55ed_row11_col3, #T_d55ed_row11_col4, #T_d55ed_row11_col6, #T_d55ed_row12_col4, #T_d55ed_row12_col6, #T_d55ed_row13_col4, #T_d55ed_row13_col6, #T_d55ed_row14_col4, #T_d55ed_row14_col6, #T_d55ed_row15_col4, #T_d55ed_row15_col5, #T_d55ed_row15_col6, #T_d55ed_row16_col4, #T_d55ed_row16_col5, #T_d55ed_row16_col6, #T_d55ed_row17_col4, #T_d55ed_row17_col5, #T_d55ed_row17_col6, #T_d55ed_row18_col1, #T_d55ed_row18_col4, #T_d55ed_row18_col5, #T_d55ed_row18_col6, #T_d55ed_row19_col4, #T_d55ed_row19_col5, #T_d55ed_row19_col6, #T_d55ed_row20_col4, #T_d55ed_row20_col5, #T_d55ed_row20_col6, #T_d55ed_row21_col4, #T_d55ed_row21_col5, #T_d55ed_row21_col6, #T_d55ed_row22_col4, #T_d55ed_row22_col5, #T_d55ed_row22_col6, #T_d55ed_row23_col4, #T_d55ed_row23_col5, #T_d55ed_row23_col6, #T_d55ed_row24_col4, #T_d55ed_row24_col6, #T_d55ed_row25_col4, #T_d55ed_row25_col6, #T_d55ed_row26_col4, #T_d55ed_row26_col5, #T_d55ed_row26_col6, #T_d55ed_row27_col2, #T_d55ed_row27_col4, #T_d55ed_row27_col6, #T_d55ed_row28_col2, #T_d55ed_row28_col4, #T_d55ed_row28_col5, #T_d55ed_row28_col6, #T_d55ed_row29_col2, #T_d55ed_row29_col4, #T_d55ed_row29_col5, #T_d55ed_row29_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d55ed_row0_col1, #T_d55ed_row27_col0 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_d55ed_row0_col2, #T_d55ed_row1_col1, #T_d55ed_row4_col3, #T_d55ed_row10_col3, #T_d55ed_row10_col5, #T_d55ed_row29_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d55ed_row0_col3, #T_d55ed_row7_col1, #T_d55ed_row9_col3, #T_d55ed_row14_col3, #T_d55ed_row27_col3 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_d55ed_row0_col5 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_d55ed_row1_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_d55ed_row1_col2 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_d55ed_row1_col3 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_d55ed_row1_col5, #T_d55ed_row2_col3, #T_d55ed_row8_col3, #T_d55ed_row12_col5, #T_d55ed_row15_col3, #T_d55ed_row16_col3, #T_d55ed_row17_col3, #T_d55ed_row18_col3, #T_d55ed_row19_col3, #T_d55ed_row20_col3, #T_d55ed_row21_col3, #T_d55ed_row22_col3, #T_d55ed_row23_col3, #T_d55ed_row24_col3, #T_d55ed_row25_col3, #T_d55ed_row26_col3, #T_d55ed_row28_col3, #T_d55ed_row29_col3 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_d55ed_row2_col0, #T_d55ed_row18_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_d55ed_row2_col1, #T_d55ed_row6_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_d55ed_row2_col2 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_d55ed_row2_col5 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_d55ed_row3_col0, #T_d55ed_row28_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_d55ed_row3_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_d55ed_row3_col2, #T_d55ed_row24_col0 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_d55ed_row3_col3 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_d55ed_row3_col5, #T_d55ed_row15_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_d55ed_row4_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_d55ed_row4_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_d55ed_row4_col2, #T_d55ed_row22_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_d55ed_row4_col5, #T_d55ed_row7_col3 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_d55ed_row5_col0, #T_d55ed_row13_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_d55ed_row5_col1 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_d55ed_row5_col2, #T_d55ed_row9_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_d55ed_row5_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_d55ed_row5_col5 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_d55ed_row6_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_d55ed_row6_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_d55ed_row6_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_d55ed_row6_col5 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_d55ed_row7_col0, #T_d55ed_row17_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_d55ed_row7_col2 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_d55ed_row7_col5 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_d55ed_row8_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_d55ed_row8_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_d55ed_row8_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_d55ed_row9_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_d55ed_row9_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_d55ed_row9_col5 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_d55ed_row10_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_d55ed_row10_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_d55ed_row10_col2 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_d55ed_row11_col0, #T_d55ed_row19_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_d55ed_row11_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_d55ed_row11_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_d55ed_row11_col5 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_d55ed_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_d55ed_row12_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_d55ed_row12_col2, #T_d55ed_row16_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_d55ed_row12_col3 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_d55ed_row13_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_d55ed_row13_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_d55ed_row13_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_d55ed_row13_col5, #T_d55ed_row25_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_d55ed_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_d55ed_row14_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_d55ed_row14_col2, #T_d55ed_row16_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_d55ed_row14_col5 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_d55ed_row15_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_d55ed_row15_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_d55ed_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_d55ed_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_d55ed_row17_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_d55ed_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_d55ed_row19_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_d55ed_row19_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_d55ed_row20_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_d55ed_row20_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_d55ed_row20_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_d55ed_row21_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_d55ed_row21_col1 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_d55ed_row21_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_d55ed_row22_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_d55ed_row22_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_d55ed_row23_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_d55ed_row23_col1 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_d55ed_row23_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_d55ed_

# %% [markdown]
# # Weight decay 1e-3 GraphConv

# %%
decay = 1e-3

# %%
experiment_name = f"ENZYMES-HomoGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{aggr} aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-{decay} decay-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HomoGNN_GraphConv(hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, aggr=aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HomoGNN_GraphConv(
#   (node_emb_layers): ModuleList(
#     (0): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): GraphConv((-1, -1), 128)
#       (post_lin): MLP(
#         (layers): ModuleList(
#           (0): Linear(-1, 128, bias=True)
#           (1): Dropout(p=0.5, inplace=False)
#           (2): Linear(128, 128, bias=True)
#         )
#       )
#     )
#   )
#   (classifier): Linear(128, 6, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, hom_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, hom_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7934 | Validation Loss: 1.7934
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0800 | Validation F1: 0.0476
#
# Epoch 2/30
# Train Loss: 1.7935 | Validation Loss: 1.7933
# Train Acc: 0.1619 | Validation Acc: 0.1667
# Train F1: 0.0744 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7932 | Validation Loss: 1.7932
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0779 | Validation F1: 0.0476
#
# Epoch 4/30
# Train Loss: 1.7933 | Validation Loss: 1.7931
# Train Acc: 0.1643 | Validation Acc: 0.1667
# Train F1: 0.0689 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7932 | Validation Loss: 1.7930
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.0830 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7930 | Validation Loss: 1.7929
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0755 | Validation F1: 0.0476
#
# Epoch 7/30
# Train Loss: 1.7932 | Validation Loss: 1.7930
# Train Acc: 0.1786 | Validation Acc: 0.1667
# Train F1: 0.0847 | Validation F1: 0.0476
#
# Epoch 8/30
# Train Loss: 1.7931 | Validation Loss: 1.7930
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.0641 | Validation F1: 0.0476
#
# Epoch 9/30
# Train Loss: 1.7932 | Validation Loss: 1.7927
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 10/30
# Train Loss: 1.7930 | Validation Loss: 1.7927
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0519 | Validation F1: 0.0476
#
# Epoch 11/30
# Train Loss: 1.7922 | Validation Loss: 1.7926
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.0828 | Validation F1: 0.0476
#
# Epoch 12/30
# Train Loss: 1.7930 | Validation Loss: 1.7925
# Train Acc: 0.1452 | Validation Acc: 0.1667
# Train F1: 0.0915 | Validation F1: 0.0476
#
# Epoch 13/30
# Train Loss: 1.7928 | Validation Loss: 1.7924
# Train Acc: 0.1571 | Validation Acc: 0.1667
# Train F1: 0.0967 | Validation F1: 0.0476
#
# Epoch 14/30
# Train Loss: 1.7925 | Validation Loss: 1.7923
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0861 | Validation F1: 0.0476
#
# Epoch 15/30
# Train Loss: 1.7921 | Validation Loss: 1.7923
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.0674 | Validation F1: 0.0476
#
# Epoch 16/30
# Train Loss: 1.7925 | Validation Loss: 1.7924
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 17/30
# Train Loss: 1.7922 | Validation Loss: 1.7923
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 18/30
# Train Loss: 1.7921 | Validation Loss: 1.7921
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 19/30
# Train Loss: 1.7917 | Validation Loss: 1.7921
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 20/30
# Train Loss: 1.7923 | Validation Loss: 1.7921
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 21/30
# Train Loss: 1.7921 | Validation Loss: 1.7921
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 22/30
# Train Loss: 1.7926 | Validation Loss: 1.7921
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 23/30
# Train Loss: 1.7925 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 24/30
# Train Loss: 1.7926 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 25/30
# Train Loss: 1.7917 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0479 | Validation F1: 0.0476
#
# Epoch 26/30
# Train Loss: 1.7919 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0478 | Validation F1: 0.0476
#
# Epoch 27/30
# Train Loss: 1.7917 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 28/30
# Train Loss: 1.7918 | Validation Loss: 1.7920
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0524 | Validation F1: 0.0476
#
# Epoch 29/30
# Train Loss: 1.7919 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 30/30
# Train Loss: 1.7920 | Validation Loss: 1.7920
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_2de0f_row0_col0, #T_2de0f_row0_col4, #T_2de0f_row0_col6, #T_2de0f_row1_col4, #T_2de0f_row1_col6, #T_2de0f_row2_col4, #T_2de0f_row2_col6, #T_2de0f_row3_col4, #T_2de0f_row3_col6, #T_2de0f_row4_col4, #T_2de0f_row4_col6, #T_2de0f_row5_col4, #T_2de0f_row5_col6, #T_2de0f_row6_col4, #T_2de0f_row6_col6, #T_2de0f_row7_col4, #T_2de0f_row7_col6, #T_2de0f_row8_col4, #T_2de0f_row8_col5, #T_2de0f_row8_col6, #T_2de0f_row9_col4, #T_2de0f_row9_col6, #T_2de0f_row10_col4, #T_2de0f_row10_col6, #T_2de0f_row11_col3, #T_2de0f_row11_col4, #T_2de0f_row11_col6, #T_2de0f_row12_col4, #T_2de0f_row12_col6, #T_2de0f_row13_col4, #T_2de0f_row13_col6, #T_2de0f_row14_col4, #T_2de0f_row14_col6, #T_2de0f_row15_col4, #T_2de0f_row15_col5, #T_2de0f_row15_col6, #T_2de0f_row16_col4, #T_2de0f_row16_col5, #T_2de0f_row16_col6, #T_2de0f_row17_col4, #T_2de0f_row17_col5, #T_2de0f_row17_col6, #T_2de0f_row18_col1, #T_2de0f_row18_col4, #T_2de0f_row18_col5, #T_2de0f_row18_col6, #T_2de0f_row19_col4, #T_2de0f_row19_col5, #T_2de0f_row19_col6, #T_2de0f_row20_col4, #T_2de0f_row20_col5, #T_2de0f_row20_col6, #T_2de0f_row21_col4, #T_2de0f_row21_col5, #T_2de0f_row21_col6, #T_2de0f_row22_col4, #T_2de0f_row22_col5, #T_2de0f_row22_col6, #T_2de0f_row23_col4, #T_2de0f_row23_col5, #T_2de0f_row23_col6, #T_2de0f_row24_col1, #T_2de0f_row24_col4, #T_2de0f_row24_col6, #T_2de0f_row25_col4, #T_2de0f_row25_col6, #T_2de0f_row26_col4, #T_2de0f_row26_col5, #T_2de0f_row26_col6, #T_2de0f_row27_col2, #T_2de0f_row27_col4, #T_2de0f_row27_col6, #T_2de0f_row28_col2, #T_2de0f_row28_col4, #T_2de0f_row28_col5, #T_2de0f_row28_col6, #T_2de0f_row29_col2, #T_2de0f_row29_col4, #T_2de0f_row29_col5, #T_2de0f_row29_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2de0f_row0_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_2de0f_row0_col2, #T_2de0f_row1_col1, #T_2de0f_row4_col3, #T_2de0f_row12_col5, #T_2de0f_row29_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2de0f_row0_col3, #T_2de0f_row5_col3, #T_2de0f_row27_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_2de0f_row0_col5 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_2de0f_row1_col0, #T_2de0f_row26_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_2de0f_row1_col2 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_2de0f_row1_col3, #T_2de0f_row10_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_2de0f_row1_col5 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_2de0f_row2_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_2de0f_row2_col1, #T_2de0f_row8_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_2de0f_row2_col2 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_2de0f_row2_col3, #T_2de0f_row8_col3, #T_2de0f_row9_col3, #T_2de0f_row12_col1, #T_2de0f_row13_col3, #T_2de0f_row15_col3, #T_2de0f_row16_col3, #T_2de0f_row17_col3, #T_2de0f_row18_col3, #T_2de0f_row19_col3, #T_2de0f_row20_col3, #T_2de0f_row21_col3, #T_2de0f_row22_col3, #T_2de0f_row23_col3, #T_2de0f_row24_col3, #T_2de0f_row25_col3, #T_2de0f_row26_col3, #T_2de0f_row28_col3, #T_2de0f_row29_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_2de0f_row2_col5, #T_2de0f_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_2de0f_row3_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_2de0f_row3_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_2de0f_row3_col2, #T_2de0f_row24_col0 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_2de0f_row3_col3, #T_2de0f_row8_col2 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_2de0f_row3_col5 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_2de0f_row4_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_2de0f_row4_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_2de0f_row4_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_2de0f_row4_col5 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_2de0f_row5_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_2de0f_row5_col1 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_2de0f_row5_col2 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_2de0f_row5_col5 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_2de0f_row6_col0, #T_2de0f_row14_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_2de0f_row6_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_2de0f_row6_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_2de0f_row6_col3, #T_2de0f_row27_col0 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_2de0f_row6_col5 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_2de0f_row7_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_2de0f_row7_col1 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_2de0f_row7_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_2de0f_row7_col3, #T_2de0f_row10_col3 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_2de0f_row7_col5 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_2de0f_row8_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_2de0f_row9_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_2de0f_row9_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_2de0f_row9_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_2de0f_row9_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_2de0f_row10_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_2de0f_row10_col1, #T_2de0f_row16_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_2de0f_row10_col5 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_2de0f_row11_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_2de0f_row11_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_2de0f_row11_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_2de0f_row11_col5, #T_2de0f_row26_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_2de0f_row12_col0, #T_2de0f_row13_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_2de0f_row12_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_2de0f_row12_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_2de0f_row13_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_2de0f_row13_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_2de0f_row13_col5 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_2de0f_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_2de0f_row14_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_2de0f_row14_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_2de0f_row14_col5 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_2de0f_row15_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_2de0f_row15_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_2de0f_row15_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_2de0f_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_2de0f_row16_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_2de0f_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_2de0f_row17_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_2de0f_row17_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_2de0f_row18_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_2de0f_row19_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_2de0f_row19_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_2de0f_row19_col2, #T_2de0f_row20_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_2de0f_row20_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_2de0f_row20_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_2de0f_row21_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_2de0f_row21_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_2de0f_row21_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_2de0f_row22_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_2de0f_row22_col1 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_2de0f_row22_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #
