# %%
from tools.utils import *
from tools.hom_networks import *

import torch

from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader

from sklearn.model_selection import train_test_split

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random
seed = 42

# Model
hidden_channels = 256
num_classes = 6
num_layers = 2
aggr = 'mean'
dropout = 0.4
use_skip_connections = True
batch_size = 8
epochs = 45
decay = 5e-4
lr = 3e-4
maxlr = 3e-4

# %% [markdown]
# # Preprocess

# %%
# Load the ENZYMES dataset
hom_dataset = TUDataset(root='data', name='ENZYMES')                          # This has 3 one-hot encodings
hom_dataset_attr = TUDataset(root='data', name='ENZYMES', use_node_attr=True) # This has 3 one-hot encodings and 18 features

# %%
def normalize_enzymes_data(data):
    data = data.clone()
    if hasattr(data, 'x') and data.x is not None:
        x = data.x
        feats = x[:, :18]
        mean = feats.mean(dim=0)
        std = feats.std(dim=0, unbiased=False)
        std[std == 0] = 1.0
        normalized_feats = (feats - mean) / std
        x[:, :18] = normalized_feats
        data.x = x
    return data

# Normalize features
normalized_hom_dataset_attr = [normalize_enzymes_data(hom_data) for hom_data in hom_dataset_attr]

# %%
# Create splits
labels = [data.y.item() for data in normalized_hom_dataset_attr]

train_set, temp_set = train_test_split(
    normalized_hom_dataset_attr, 
    test_size=0.3, 
    stratify=labels,
    random_state=seed
    
)

temp_labels = [data.y.item() for data in temp_set]
valid_set, test_set = train_test_split(
    temp_set, 
    test_size=0.5, 
    stratify=temp_labels,
    random_state=seed
)

# train_loader is defined at each experiment for reproducibility
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Tuning HomoGNN

# %%
experiment_name = f"ENZYMES-HomoGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{aggr} aggr-{dropout} dropout-use skip {use_skip_connections}-{lr} lr-{maxlr} maxlr-{decay} decay-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HomoGNN_GraphConv(hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, aggr=aggr, dropout=dropout, use_skip_connections=use_skip_connections).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay)
criterion = torch.nn.CrossEntropyLoss()
model
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, hom_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, hom_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# Epoch 1/45
# Train Loss: 1.8073 | Validation Loss: 1.7984
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 2/45
# Train Loss: 1.8034 | Validation Loss: 1.7935
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0524 | Validation F1: 0.0476
#
# Epoch 3/45
# Train Loss: 1.7959 | Validation Loss: 1.7902
# Train Acc: 0.1738 | Validation Acc: 0.1556
# Train F1: 0.0639 | Validation F1: 0.0449
#
# Epoch 4/45
# Train Loss: 1.7978 | Validation Loss: 1.7880
# Train Acc: 0.1619 | Validation Acc: 0.2333
# Train F1: 0.0856 | Validation F1: 0.1523
#
# Epoch 5/45
# Train Loss: 1.7906 | Validation Loss: 1.7866
# Train Acc: 0.1952 | Validation Acc: 0.1667
# Train F1: 0.1709 | Validation F1: 0.0485
#
# Epoch 6/45
# Train Loss: 1.7913 | Validation Loss: 1.7834
# Train Acc: 0.1810 | Validation Acc: 0.2333
# Train F1: 0.1360 | Validation F1: 0.1204
#
# Epoch 7/45
# Train Loss: 1.7901 | Validation Loss: 1.7796
# Train Acc: 0.1667 | Validation Acc: 0.2000
# Train F1: 0.1117 | Validation F1: 0.1072
#
# Epoch 8/45
# Train Loss: 1.7888 | Validation Loss: 1.7761
# Train Acc: 0.1667 | Validation Acc: 0.2333
# Train F1: 0.1157 | Validation F1: 0.1466
#
# Epoch 9/45
# Train Loss: 1.7865 | Validation Loss: 1.7702
# Train Acc: 0.2095 | Validation Acc: 0.3222
# Train F1: 0.1749 | Validation F1: 0.2827
#
# Epoch 10/45
# Train Loss: 1.7784 | Validation Loss: 1.7633
# Train Acc: 0.2310 | Validation Acc: 0.2667
# Train F1: 0.1988 | Validation F1: 0.1706
#
# Epoch 11/45
# Train Loss: 1.7806 | Validation Loss: 1.7508
# Train Acc: 0.1810 | Validation Acc: 0.3222
# Train F1: 0.1755 | Validation F1: 0.2626
#
# Epoch 12/45
# Train Loss: 1.7475 | Validation Loss: 1.7094
# Train Acc: 0.2333 | Validation Acc: 0.2333
# Train F1: 0.1933 | Validation F1: 0.1570
#
# Epoch 13/45
# Train Loss: 1.7459 | Validation Loss: 1.7354
# Train Acc: 0.2333 | Validation Acc: 0.2778
# Train F1: 0.2233 | Validation F1: 0.2065
#
# Epoch 14/45
# Train Loss: 1.7254 | Validation Loss: 1.7046
# Train Acc: 0.2571 | Validation Acc: 0.3556
# Train F1: 0.2509 | Validation F1: 0.3305
#
# Epoch 15/45
# Train Loss: 1.7175 | Validation Loss: 1.7128
# Train Acc: 0.2619 | Validation Acc: 0.2556
# Train F1: 0.2550 | Validation F1: 0.1810
#
# Epoch 16/45
# Train Loss: 1.7169 | Validation Loss: 1.7106
# Train Acc: 0.2524 | Validation Acc: 0.3000
# Train F1: 0.2539 | Validation F1: 0.2379
#
# Epoch 17/45
# Train Loss: 1.7031 | Validation Loss: 1.6992
# Train Acc: 0.2571 | Validation Acc: 0.3333
# Train F1: 0.2259 | Validation F1: 0.2989
#
# Epoch 18/45
# Train Loss: 1.6834 | Validation Loss: 1.6887
# Train Acc: 0.3286 | Validation Acc: 0.3556
# Train F1: 0.3033 | Validation F1: 0.3232
#
# Epoch 19/45
# Train Loss: 1.6632 | Validation Loss: 1.6361
# Train Acc: 0.3452 | Validation Acc: 0.3000
# Train F1: 0.3428 | Validation F1: 0.2328
#
# Epoch 20/45
# Train Loss: 1.6688 | Validation Loss: 1.6370
# Train Acc: 0.2810 | Validation Acc: 0.3667
# Train F1: 0.2590 | Validation F1: 0.3456
#
# Epoch 21/45
# Train Loss: 1.6623 | Validation Loss: 1.6198
# Train Acc: 0.3190 | Validation Acc: 0.3778
# Train F1: 0.3145 | Validation F1: 0.3234
#
# Epoch 22/45
# Train Loss: 1.6388 | Validation Loss: 1.6602
# Train Acc: 0.3524 | Validation Acc: 0.4000
# Train F1: 0.3520 | Validation F1: 0.3859
#
# Epoch 23/45
# Train Loss: 1.6359 | Validation Loss: 1.6039
# Train Acc: 0.3167 | Validation Acc: 0.4222
# Train F1: 0.2988 | Validation F1: 0.4173
#
# Epoch 24/45
# Train Loss: 1.5921 | Validation Loss: 1.5994
# Train Acc: 0.3619 | Validation Acc: 0.3667
# Train F1: 0.3488 | Validation F1: 0.3478
#
# Epoch 25/45
# Train Loss: 1.5823 | Validation Loss: 1.6083
# Train Acc: 0.3619 | Validation Acc: 0.3444
# Train F1: 0.3386 | Validation F1: 0.3054
#
# Epoch 26/45
# Train Loss: 1.5356 | Validation Loss: 1.6215
# Train Acc: 0.3619 | Validation Acc: 0.3778
# Train F1: 0.3424 | Validation F1: 0.3585
#
# Epoch 27/45
# Train Loss: 1.5098 | Validation Loss: 1.6077
# Train Acc: 0.3524 | Validation Acc: 0.3444
# Train F1: 0.3430 | Validation F1: 0.2991
#
# Epoch 28/45
# Train Loss: 1.4581 | Validation Loss: 1.6782
# Train Acc: 0.4071 | Validation Acc: 0.2778
# Train F1: 0.4010 | Validation F1: 0.2501
#
# Epoch 29/45
# Train Loss: 1.4536 | Validation Loss: 1.5956
# Train Acc: 0.4286 | Validation Acc: 0.3556
# Train F1: 0.4231 | Validation F1: 0.3353
#
# Epoch 30/45
# Train Loss: 1.3856 | Validation Loss: 1.5988
# Train Acc: 0.4810 | Validation Acc: 0.3778
# Train F1: 0.4747 | Validation F1: 0.3750
#
# Epoch 31/45
# Train Loss: 1.4067 | Validation Loss: 1.6060
# Train Acc: 0.4476 | Validation Acc: 0.4000
# Train F1: 0.4290 | Validation F1: 0.3980
#
# Epoch 32/45
# Train Loss: 1.3653 | Validation Loss: 1.5492
# Train Acc: 0.4595 | Validation Acc: 0.4333
# Train F1: 0.4578 | Validation F1: 0.4129
#
# Epoch 33/45
# Train Loss: 1.3424 | Validation Loss: 1.5762
# Train Acc: 0.4952 | Validation Acc: 0.4111
# Train F1: 0.4758 | Validation F1: 0.4051
#
# Epoch 34/45
# Train Loss: 1.2999 | Validation Loss: 1.6315
# Train Acc: 0.5071 | Validation Acc: 0.4111
# Train F1: 0.5014 | Validation F1: 0.4005
#
# Epoch 35/45
# Train Loss: 1.2941 | Validation Loss: 1.5776
# Train Acc: 0.5214 | Validation Acc: 0.4222
# Train F1: 0.5196 | Validation F1: 0.4148
#
# Epoch 36/45
# Train Loss: 1.3070 | Validation Loss: 1.5689
# Train Acc: 0.5024 | Validation Acc: 0.4556
# Train F1: 0.4862 | Validation F1: 0.4479
#
# Epoch 37/45
# Train Loss: 1.2603 | Validation Loss: 1.6004
# Train Acc: 0.5238 | Validation Acc: 0.4111
# Train F1: 0.5160 | Validation F1: 0.4108
#
# Epoch 38/45
# Train Loss: 1.2676 | Validation Loss: 1.5542
# Train Acc: 0.4833 | Validation Acc: 0.4111
# Train F1: 0.4739 | Validation F1: 0.3943
#
# Epoch 39/45
# Train Loss: 1.2746 | Validation Loss: 1.5765
# Train Acc: 0.5119 | Validation Acc: 0.4667
# Train F1: 0.4916 | Validation F1: 0.4626
#
# Epoch 40/45
# Train Loss: 1.2647 | Validation Loss: 1.5744
# Train Acc: 0.5048 | Validation Acc: 0.4111
# Train F1: 0.4943 | Validation F1: 0.4021
#
# Epoch 41/45
# Train Loss: 1.2494 | Validation Loss: 1.5666
# Train Acc: 0.5071 | Validation Acc: 0.4444
# Train F1: 0.4940 | Validation F1: 0.4400
#
# Epoch 42/45
# Train Loss: 1.2457 | Validation Loss: 1.5652
# Train Acc: 0.5190 | Validation Acc: 0.4556
# Train F1: 0.5110 | Validation F1: 0.4492
#
# Epoch 43/45
# Train Loss: 1.2675 | Validation Loss: 1.5645
# Train Acc: 0.5095 | Validation Acc: 0.4556
# Train F1: 0.4954 | Validation F1: 0.4480
#
# Epoch 44/45
# Train Loss: 1.2272 | Validation Loss: 1.5693
# Train Acc: 0.5000 | Validation Acc: 0.4444
# Train F1: 0.4974 | Validation F1: 0.4399
#
# Epoch 45/45
# Train Loss: 1.2214 | Validation Loss: 1.5699
# Train Acc: 0.5381 | Validation Acc: 0.4444
# Train F1: 0.5293 | Validation F1: 0.4399
# <style type="text/css">
# #T_098a0_row0_col0, #T_098a0_row0_col5, #T_098a0_row2_col4, #T_098a0_row2_col6, #T_098a0_row3_col3, #T_098a0_row31_col2, #T_098a0_row44_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_098a0_row0_col1, #T_098a0_row0_col2, #T_098a0_row38_col4, #T_098a0_row38_col6, #T_098a0_row44_col0, #T_098a0_row44_col3, #T_098a0_row44_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_098a0_row0_col3, #T_098a0_row6_col3, #T_098a0_row7_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_098a0_row0_col4, #T_098a0_row1_col4, #T_098a0_row4_col4 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_098a0_row0_col6, #T_098a0_row1_col6 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_098a0_row1_col0, #T_098a0_row37_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_098a0_row1_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_098a0_row1_col2, #T_098a0_row2_col1, #T_098a0_row3_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_098a0_row1_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_098a0_row1_col5, #T_098a0_row4_col6, #T_098a0_row43_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_098a0_row2_col0, #T_098a0_row5_col3, #T_098a0_row10_col3, #T_098a0_row40_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_098a0_row2_col2, #T_098a0_row7_col1, #T_098a0_row35_col6, #T_098a0_row41_col6, #T_098a0_row42_col6 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_098a0_row2_col3, #T_098a0_row2_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_098a0_row3_col0, #T_098a0_row36_col1, #T_098a0_row40_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_098a0_row3_col2 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_098a0_row3_col4, #T_098a0_row5_col4, #T_098a0_row7_col4, #T_098a0_row11_col0, #T_098a0_row11_col4, #T_098a0_row13_col3, #T_098a0_row16_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_098a0_row3_col5, #T_098a0_row35_col2, #T_098a0_row37_col1, #T_098a0_row42_col1, #T_098a0_row43_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_098a0_row3_col6, #T_098a0_row4_col5 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_098a0_row4_col0, #T_098a0_row38_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_098a0_row4_col1, #T_098a0_row5_col1, #T_098a0_row6_col1, #T_098a0_row36_col5 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_098a0_row4_col2, #T_098a0_row9_col1, #T_098a0_row41_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_098a0_row4_col3 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_098a0_row5_col0, #T_098a0_row34_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_098a0_row5_col2 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_098a0_row5_col5, #T_098a0_row5_col6, #T_098a0_row8_col0, #T_098a0_row9_col3 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_098a0_row6_col0, #T_098a0_row6_col5, #T_098a0_row33_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_098a0_row6_col2, #T_098a0_row42_col3 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_098a0_row6_col4, #T_098a0_row7_col5 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_098a0_row6_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_098a0_row7_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_098a0_row7_col2, #T_098a0_row35_col5, #T_098a0_row39_col3 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_098a0_row7_col6, #T_098a0_row31_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_098a0_row8_col1, #T_098a0_row35_col4, #T_098a0_row36_col3, #T_098a0_row41_col4, #T_098a0_row41_col5, #T_098a0_row42_col4 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_098a0_row8_col2, #T_098a0_row32_col5 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_098a0_row8_col3 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_098a0_row8_col4, #T_098a0_row10_col4, #T_098a0_row25_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_098a0_row8_col5, #T_098a0_row10_col5 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_098a0_row8_col6, #T_098a0_row25_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_098a0_row9_col0, #T_098a0_row32_col1, #T_098a0_row36_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_098a0_row9_col2, #T_098a0_row22_col4, #T_098a0_row34_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_098a0_row9_col4 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_098a0_row9_col5, #T_098a0_row30_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_098a0_row9_col6, #T_098a0_row11_col5 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_098a0_row10_col0, #T_098a0_row30_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_098a0_row10_col1, #T_098a0_row34_col3, #T_098a0_row42_col0 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_098a0_row10_col2 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_098a0_row10_col6, #T_098a0_row22_col5, #T_098a0_row23_col0 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_098a0_row11_col1, #T_098a0_row12_col1 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_098a0_row11_col2, #T_098a0_row13_col4, #T_098a0_row17_col4, #T_098a0_row28_col4 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_098a0_row11_col3, #T_098a0_row12_col3 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_098a0_row11_col6, #T_098a0_row14_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_098a0_row12_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_098a0_row12_col2 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_098a0_row12_col4, #T_098a0_row27_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_098a0_row12_col5, #T_098a0_row16_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_098a0_row12_col6 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_098a0_row13_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_098a0_row13_col1, #T_098a0_row32_col6 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_098a0_row13_col2, #T_098a0_row24_col6 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_098a0_row13_col5 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_098a0_row13_col6 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_098a0_row14_col0, #T_098a0_row19_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_098a0_row14_col1, #T_098a0_row15_col1, #T_098a0_row30_col6 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_098a0_row14_col2, #T_098a0_row29_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_098a0_row14_col4 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_098a0_row14_col5, #T_098a0_row19_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_098a0_row14_col6 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_098a0_row15_col0 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_098a0_row15_col2 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_098a0_row15_col3 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_098a0_row15_col4, #T_098a0_row15_col6, #T_098a0_row18_col4 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_098a0_row15_col5 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_098a0_row16_col1, #T_098a0_row32_col4, #T_098a0_row33_col4, #T_098a0_row36_col4, #T_098a0_row37_col4, #T_098a0_row39_col4 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_098a0_row16_col2, #T_098a0_row24_col5 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_098a0_row16_col4 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_098a0_row16_col5 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_098a0_row16_col6, #T_098a0_row24_col4, #T_098a0_row26_col4, #T_098a0_row26_col6 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_098a0_row17_col0 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_098a0_row17_col1, #T_098a0_row21_col4, #T_098a0_row30_col4 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_098a0_row17_col2 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_098a0_row17_col3 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_098
