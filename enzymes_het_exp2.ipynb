# %%
from tools.utils import *
from tools.het_networks import *

import torch

from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader

from sklearn.model_selection import train_test_split

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random
seed = 42

# Model
hidden_channels = 128
num_classes = 6
num_layers = 2
intra_aggr='mean'
inter_aggr='sum'
# dropout = varying this below

# Training
batch_size = 32
epochs = 30
lr = 1e-4
maxlr = 3e-4

# %% [markdown]
# # Preprocessing

# %%
# Load the ENZYMES dataset
hom_dataset = TUDataset(root='data', name='ENZYMES')                          # This has 3 one-hot encodings
hom_dataset_attr = TUDataset(root='data', name='ENZYMES', use_node_attr=True) # This has 3 one-hot encodings and 18 features

# %%
def normalize_enzymes_data(data):
    data = data.clone()
    if hasattr(data, 'x') and data.x is not None:
        x = data.x
        feats = x[:, :18]
        mean = feats.mean(dim=0)
        std = feats.std(dim=0, unbiased=False)
        std[std == 0] = 1.0
        normalized_feats = (feats - mean) / std
        x[:, :18] = normalized_feats
        data.x = x
    return data

# Normalize features
normalized_hom_dataset_attr = [normalize_enzymes_data(hom_data) for hom_data in hom_dataset_attr]

# %%
# Construct het dataset
het_dataset = []
for hom_data in normalized_hom_dataset_attr:
    het_data = convert_hom_to_het(hom_data, onehot_indices=[18, 19, 20], is_directed=False)
    het_dataset.append(het_data)
het_dataset.__len__()
# Out:
# 600

# %%
# Get the metadata to build HeteroGNN
edge_types = het_dataset[0].edge_types
node_types = het_dataset[0].node_types
metadata = (node_types, edge_types)
metadata
# Out:
# (['A', 'B', 'C'],
#  [('A', 'edge_index', 'A'),
#   ('A', 'edge_index', 'B'),
#   ('A', 'edge_index', 'C'),
#   ('B', 'edge_index', 'B'),
#   ('B', 'edge_index', 'C'),
#   ('C', 'edge_index', 'C')])

# %%
# Create splits
labels = [data.y.item() for data in het_dataset]

train_set, temp_set = train_test_split(
    het_dataset, 
    test_size=0.3, 
    stratify=labels,
    random_state=seed
    
)

temp_labels = [data.y.item() for data in temp_set]
valid_set, test_set = train_test_split(
    temp_set, 
    test_size=0.5, 
    stratify=temp_labels,
    random_state=seed
)

# train_loader is defined at each experiment for reproducibility
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Dropout 0.0 GraphConv

# %%
dropout = 0.0

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.0, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.0, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.0, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7924 | Validation Loss: 1.7925
# Train Acc: 0.1619 | Validation Acc: 0.1667
# Train F1: 0.0466 | Validation F1: 0.0476
#
# Epoch 2/30
# Train Loss: 1.7922 | Validation Loss: 1.7923
# Train Acc: 0.1619 | Validation Acc: 0.1667
# Train F1: 0.0466 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7917 | Validation Loss: 1.7919
# Train Acc: 0.1690 | Validation Acc: 0.1556
# Train F1: 0.0598 | Validation F1: 0.0471
#
# Epoch 4/30
# Train Loss: 1.7910 | Validation Loss: 1.7911
# Train Acc: 0.1643 | Validation Acc: 0.1556
# Train F1: 0.1000 | Validation F1: 0.0954
#
# Epoch 5/30
# Train Loss: 1.7893 | Validation Loss: 1.7889
# Train Acc: 0.2286 | Validation Acc: 0.2000
# Train F1: 0.1297 | Validation F1: 0.1306
#
# Epoch 6/30
# Train Loss: 1.7820 | Validation Loss: 1.7823
# Train Acc: 0.2738 | Validation Acc: 0.1889
# Train F1: 0.2020 | Validation F1: 0.1000
#
# Epoch 7/30
# Train Loss: 1.7700 | Validation Loss: 1.7716
# Train Acc: 0.2524 | Validation Acc: 0.1778
# Train F1: 0.1597 | Validation F1: 0.1012
#
# Epoch 8/30
# Train Loss: 1.7522 | Validation Loss: 1.7672
# Train Acc: 0.2524 | Validation Acc: 0.1889
# Train F1: 0.1607 | Validation F1: 0.1061
#
# Epoch 9/30
# Train Loss: 1.6987 | Validation Loss: 1.7889
# Train Acc: 0.2429 | Validation Acc: 0.1889
# Train F1: 0.1973 | Validation F1: 0.1493
#
# Epoch 10/30
# Train Loss: 1.6866 | Validation Loss: 1.7467
# Train Acc: 0.2786 | Validation Acc: 0.2333
# Train F1: 0.2337 | Validation F1: 0.1716
#
# Epoch 11/30
{
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_85922_row10_col4, #T_85922_row11_col4, #T_85922_row16_col4 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_85922_row10_col5, #T_85922_row12_col3, #T_85922_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_85922_row10_col6 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_85922_row11_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_85922_row11_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_85922_row11_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_85922_row11_col3, #T_85922_row13_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_85922_row11_col5 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_85922_row11_col6 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_85922_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_85922_row12_col1, #T_85922_row15_col6, #T_85922_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_85922_row12_col5 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_85922_row12_col6 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_85922_row13_col1, #T_85922_row14_col6 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_85922_row13_col2 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_85922_row13_col3, #T_85922_row16_col6 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_85922_row13_col4 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_85922_row13_col5 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_85922_row13_col6, #T_85922_row19_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_85922_row14_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_85922_row14_col2, #T_85922_row14_col4, #T_85922_row19_col4 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_85922_row14_col3 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_85922_row14_col5 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_85922_row15_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_85922_row15_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_85922_row15_col3, #T_85922_row18_col4 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_85922_row15_col4 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_85922_row15_col5 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_85922_row16_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_85922_row16_col3, #T_85922_row17_col4, #T_85922_row21_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_85922_row16_col5, #T_85922_row17_col6, #T_85922_row20_col4 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_85922_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_85922_row17_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_85922_row17_col3, #T_85922_row22_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_85922_row17_col5 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_85922_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_85922_row18_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_85922_row18_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_85922_row18_col3 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_85922_row18_col5, #T_85922_row23_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_85922_row18_col6 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_85922_row19_col1, #T_85922_row23_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_85922_row19_col5 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_85922_row19_col

# %% [markdown]
# # Dropout 0.25 GraphConv

# %%
dropout = 0.25

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.25, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.25, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.25, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.25, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.25, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.25, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7926 | Validation Loss: 1.7924
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.0918 | Validation F1: 0.0481
#
# Epoch 2/30
# Train Loss: 1.7922 | Validation Loss: 1.7922
# Train Acc: 0.1786 | Validation Acc: 0.1556
# Train F1: 0.0927 | Validation F1: 0.0481
#
# Epoch 3/30
# Train Loss: 1.7920 | Validation Loss: 1.7918
# Train Acc: 0.1857 | Validation Acc: 0.1889
# Train F1: 0.0979 | Validation F1: 0.0793
#
# Epoch 4/30
# Train Loss: 1.7912 | Validation Loss: 1.7911
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0715 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7896 | Validation Loss: 1.7886
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.0575 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7813 | Validation Loss: 1.7840
# Train Acc: 0.2119 | Validation Acc: 0.1889
# Train F1: 0.1368 | Validation F1: 0.0945
#
# Epoch 7/30
# Train Loss: 1.7735 | Validation Loss: 1.7728
# Train Acc: 0.2524 | Validation Acc: 0.2000
# Train F1: 0.1601 | Validation F1: 0.1078
#
# Epoch 8/30
# Train Loss: 1.7591 | Validation Loss: 1.7708
# Train Acc: 0.2524 | Validation Acc: 0.1778
# Train F1: 0.1601 | Validation F1: 0.0990
#
# Epoch 9/30
# Train Loss: 1.7212 | Validation Loss: 1.7840
# Train Acc: 0.2143 | Validation Acc: 0.1556
# Train F1: 0.1612 | Validation F1: 0.1173
#
# Epoch 10/30
# Train Loss: 1.7060 | Validation Loss: 1.7662
# Train Acc: 0.2595 | Validation Acc: 0.2000
# Train F1: 0.2186 | Validation F1: 0.1349
#
# Epoch 11/30
# Train Loss: 1.6801 | Validation Loss: 1.7565
# Train Acc: 0.3024 | Validation Acc: 0.2444
# Train F1: 0.2434 | Validation F1: 0.1825
#
# Epoch 12/30
# Train Loss: 1.6482 | Validation Loss: 1.7286
# Train Acc: 0.3167 | Validation Acc: 0.2444
# Train F1: 0.2478 | Validation F1: 0.1823
#
# Epoch 13/30
# Train Loss: 1.6112 | Validation Loss: 1.7283
# Train Acc: 0.3167 | Validation Acc: 0.2000
# Train F1: 0.2941 | Validation F1: 0.1745
#
# Epoch 14/30
# Train Loss: 1.5980 | Validation Loss: 1.7834
# Train Acc: 0.3024 | Validation Acc: 0.2444
# Train F1: 0.2686 | Validation F1: 0.1556
#
# Epoch 15/30
# Train Loss: 1.6030 | Validation Loss: 1.7074
# Train Acc: 0.3167 | Validation Acc: 0.2000
# Train F1: 0.2625 | Validation F1: 0.1646
#
# Epoch 16/30
# Train Loss: 1.5474 | Validation Loss: 1.6885
# Train Acc: 0.3405 | Validation Acc: 0.2444
# Train F1: 0.2760 | Validation F1: 0.1970
#
# Epoch 17/30
# Train Loss: 1.5198 | Validation Loss: 1.6838
# Train Acc: 0.3643 | Validation Acc: 0.2444
# Train F1: 0.3365 | Validation F1: 0.2181
#
# Epoch 18/30
# Train Loss: 1.5079 | Validation Loss: 1.6575
# Train Acc: 0.3548 | Validation Acc: 0.2667
# Train F1: 0.3263 | Validation F1: 0.2342
#
# Epoch 19/30
# Train Loss: 1.4890 | Validation Loss: 1.6687
# Train Acc: 0.4000 | Validation Acc: 0.2222
# Train F1: 0.3602 | Validation F1: 0.2137
#
# Epoch 20/30
# Train Loss: 1.4736 | Validation Loss: 1.6633
# Train Acc: 0.4095 | Validation Acc: 0.2444
# Train F1: 0.3853 | Validation F1: 0.2349
#
# Epoch 21/30
# Train Loss: 1.4453 | Validation Loss: 1.6486
# Train Acc: 0.3952 | Validation Acc: 0.2556
# Train F1: 0.3804 | Validation F1: 0.2382
#
# Epoch 22/30
# Train Loss: 1.4329 | Validation Loss: 1.6439
# Train Acc: 0.4238 | Validation Acc: 0.2556
# Train F1: 0.3939 | Validation F1: 0.2374
#
# Epoch 23/30
# Train Loss: 1.4229 | Validation Loss: 1.6404
# Train Acc: 0.4119 | Validation Acc: 0.2778
# Train F1: 0.3847 | Validation F1: 0.2546
#
# Epoch 24/30
# Train Loss: 1.4158 | Validation Loss: 1.6349
# Train Acc: 0.4167 | Validation Acc: 0.2778
# Train F1: 0.3900 | Validation F1: 0.2570
#
# Epoch 25/30
# Train Loss: 1.4179 | Validation Loss: 1.6333
# Train Acc: 0.4214 | Validation Acc: 0.2667
# Train F1: 0.4077 | Validation F1: 0.2528
#
# Epoch 26/30
# Train Loss: 1.3984 | Validation Loss: 1.6270
# Train Acc: 0.4262 | Validation Acc: 0.2778
# Train F1: 0.4117 | Validation F1: 0.2659
#
# Epoch 27/30
# Train Loss: 1.4015 | Validation Loss: 1.6261
# Train Acc: 0.4452 | Validation Acc: 0.2889
# Train F1: 0.4252 | Validation F1: 0.2731
#
# Epoch 28/30
# Train Loss: 1.4002 | Validation Loss: 1.6262
# Train Acc: 0.4310 | Validation Acc: 0.2778
# Train F1: 0.4109 | Validation F1: 0.2625
#
# Epoch 29/30
# Train Loss: 1.4018 | Validation Loss: 1.6258
# Train Acc: 0.4381 | Validation Acc: 0.2889
# Train F1: 0.4177 | Validation F1: 0.2757
#
# Epoch 30/30
# Train Loss: 1.4016 | Validation Loss: 1.6258
# Train Acc: 0.4381 | Validation Acc: 0.2889
# Train F1: 0.4229 | Validation F1: 0.2757

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_33bb5_row0_col0, #T_33bb5_row0_col6, #T_33bb5_row1_col4, #T_33bb5_row1_col6, #T_33bb5_row3_col3, #T_33bb5_row3_col6, #T_33bb5_row4_col5, #T_33bb5_row4_col6, #T_33bb5_row8_col4, #T_33bb5_row25_col1, #T_33bb5_row26_col2, #T_33bb5_row27_col2, #T_33bb5_row28_col2, #T_33bb5_row29_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T
{
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_33bb5_row10_col6, #T_33bb5_row11_col6 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_33bb5_row11_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_33bb5_row11_col2, #T_33bb5_row12_col2 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_33bb5_row11_col3, #T_33bb5_row12_col3, #T_33bb5_row14_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_33bb5_row11_col5, #T_33bb5_row14_col1, #T_33bb5_row15_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_33bb5_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_33bb5_row12_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_33bb5_row12_col5 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_33bb5_row12_col6, #T_33bb5_row14_col5 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_33bb5_row13_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_33bb5_row13_col2, #T_33bb5_row27_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_33bb5_row13_col5 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_33bb5_row13_col6 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_33bb5_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_33bb5_row14_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_33bb5_row14_col6 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_33bb5_row15_col1, #T_33bb5_row15_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_33bb5_row15_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_33bb5_row15_col5 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_33bb5_row15_col6, #T_33bb5_row19_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_33bb5_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_33bb5_row16_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_33bb5_row16_col3 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_33bb5_row16_col5, #T_33bb5_row22_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_33bb5_row16_col6 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_33bb5_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_33bb5_row17_col2, #T_33bb5_row19_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_33bb5_row17_col3 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_33bb5_row17_col4, #T_33bb5_row20_col6, #T_33bb5_row24_col4 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_33bb5_row17_col5 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_33bb5_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_33bb5_row18_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_33bb5_row18_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_33bb5_row18_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_33bb5_row18_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_33bb5_row18_col5, #T_33bb5_row19_col6, #T_33bb5_row20_col3 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_33bb5_row18_col6 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_33bb5_row19_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_33bb5_row19_col5 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_33bb5_row20_col0 {
#   background

# %% [markdown]
# # Dropout 0.5 GraphConv

# %%
dropout = 0.5

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7928 | Validation Loss: 1.7924
# Train Acc: 0.1333 | Validation Acc: 0.1667
# Train F1: 0.0745 | Validation F1: 0.0481
#
# Epoch 2/30
# Train Loss: 1.7922 | Validation Loss: 1.7923
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.1055 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7923 | Validation Loss: 1.7921
# Train Acc: 0.1833 | Validation Acc: 0.1667
# Train F1: 0.1081 | Validation F1: 0.0490
#
# Epoch 4/30
# Train Loss: 1.7915 | Validation Loss: 1.7916
# Train Acc: 0.1786 | Validation Acc: 0.1667
# Train F1: 0.1108 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7911 | Validation Loss: 1.7907
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.0813 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7876 | Validation Loss: 1.7884
# Train Acc: 0.1810 | Validation Acc: 0.2000
# Train F1: 0.1175 | Validation F1: 0.1085
#
# Epoch 7/30
# Train Loss: 1.7812 | Validation Loss: 1.7788
# Train Acc: 0.1762 | Validation Acc: 0.1444
# Train F1: 0.1121 | Validation F1: 0.0563
#
# Epoch 8/30
# Train Loss: 1.7705 | Validation Loss: 1.7829
# Train Acc: 0.1810 | Validation Acc: 0.1444
# Train F1: 0.1002 | Validation F1: 0.0563
#
# Epoch 9/30
# Train Loss: 1.7664 | Validation Loss: 1.7826
# Train Acc: 0.2429 | Validation Acc: 0.1556
# Train F1: 0.1840 | Validation F1: 0.1139
#
# Epoch 10/30
# Train Loss: 1.7586 | Validation Loss: 1.7736
# Train Acc: 0.2262 | Validation Acc: 0.2333
# Train F1: 0.1781 | Validation F1: 0.1521
#
# Epoch 11/30
# Train Loss: 1.7502 | Validation Loss: 1.7632
# Train Acc: 0.2405 | Validation Acc: 0.2333
# Train F1: 0.2189 | Validation F1: 0.1707
#
# Epoch 12/30
# Train Loss: 1.7275 | Validation Loss: 1.7471
# Train Acc: 0.2643 | Validation Acc: 0.2556
# Train F1: 0.2287 | Validation F1: 0.1695
#
# Epoch 13/30
# Train Loss: 1.6976 | Validation Loss: 1.7567
# Train Acc: 0.2524 | Validation Acc: 0.1889
# Train F1: 0.2236 | Validation F1: 0.1419
#
# Epoch 14/30
# Train Loss: 1.6923 | Validation Loss: 1.7564
# Train Acc: 0.2548 | Validation Acc: 0.2444
# Train F1: 0.2080 | Validation F1: 0.1909
#
# Epoch 15/30
# Train Loss: 1.6869 | Validation Loss: 1.7460
# Train Acc: 0.2976 | Validation Acc: 0.2333
# Train F1: 0.2366 | Validation F1: 0.1727
#
# Epoch 16/30
# Train Loss: 1.6532 | Validation Loss: 1.7307
# Train Acc: 0.3024 | Validation Acc: 0.2222
# Train F1: 0.2448 | Validation F1: 0.1545
#
# Epoch 17/30
# Train Loss: 1.6389 | Validation Loss: 1.7297
# Train Acc: 0.3048 | Validation Acc: 0.2000
# Train F1: 0.2697 | Validation F1: 0.1641
#
# Epoch 18/30
# Train Loss: 1.6299 | Validation Loss: 1.7155
# Train Acc: 0.3071 | Validation Acc: 0.2222
# Train F1: 0.2763 | Validation F1: 0.1614
#
# Epoch 19/30
# Train Loss: 1.6249 | Validation Loss: 1.7153
# Train Acc: 0.3214 | Validation Acc: 0.2333
# Train F1: 0.2925 | Validation F1: 0.1771
#
# Epoch 20/30
# Train Loss: 1.6158 | Validation Loss: 1.6981
# Train Acc: 0.3286 | Validation Acc: 0.2333
# Train F1: 0.2889 | Validation F1: 0.1895
#
# Epoch 21/30
# Train Loss: 1.5879 | Validation Loss: 1.6960
# Train Acc: 0.3357 | Validation Acc: 0.2111
# Train F1: 0.3096 | Validation F1: 0.1561
#
# Epoch 22/30
# Train Loss: 1.5770 | Validation Loss: 1.6876
# Train Acc: 0.3452 | Validation Acc: 0.2556
# Train F1: 0.2955 | Validation F1: 0.2142
#
# Epoch 23/30
# Train Loss: 1.5687 | Validation Loss: 1.6809
# Train Acc: 0.3405 | Validation Acc: 0.2556
# Train F1: 0.2987 | Validation F1: 0.2138
#
# Epoch 24/30
# Train Loss: 1.5635 | Validation Loss: 1.6753
# Train Acc: 0.3262 | Validation Acc: 0.2667
# Train F1: 0.2933 | Validation F1: 0.2211
#
# Epoch 25/30
# Train Loss: 1.5649 | Validation Loss: 1.6728
# Train Acc: 0.3262 | Validation Acc: 0.2444
# Train F1: 0.3018 | Validation F1: 0.1928
#
# Epoch 26/30
# Train Loss: 1.5558 | Validation Loss: 1.6653
# Train Acc: 0.3310 | Validation Acc: 0.2778
# Train F1: 0.3078 | Validation F1: 0.2376
#
# Epoch 27/30
# Train Loss: 1.5397 | Validation Loss: 1.6639
# Train Acc: 0.3738 | Validation Acc: 0.3000
# Train F1: 0.3514 | Validation F1: 0.2678
#
# Epoch 28/30
# Train Loss: 1.5515 | Validation Loss: 1.6640
# Train Acc: 0.3500 | Validation Acc: 0.3000
# Train F1: 0.3283 | Validation F1: 0.2678
#
# Epoch 29/30
# Train Loss: 1.5389 | Validation Loss: 1.6636
# Train Acc: 0.3595 | Validation Acc: 0.3000
# Train F1: 0.3366 | Validation F1: 0.2678
#
# Epoch 30/30
# Train Loss: 1.5513 | Validation Loss: 1.6636
# Train Acc: 0.3452 | Validation Acc: 0.3000
# Train F1: 0.3164 | Validation F1: 0.2672

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
{
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_202b9_row12_col3, #T_202b9_row20_col6 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_202b9_row12_col4 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_202b9_row12_col5 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_202b9_row12_col6, #T_202b9_row20_col4 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_202b9_row13_col1 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_202b9_row13_col3 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_202b9_row13_col4, #T_202b9_row24_col4 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_202b9_row13_col5, #T_202b9_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_202b9_row14_col1, #T_202b9_row14_col5 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_202b9_row14_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_202b9_row14_col3 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_202b9_row14_col6 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_202b9_row15_col0, #T_202b9_row17_col6 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_202b9_row15_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_202b9_row15_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_202b9_row15_col4, #T_202b9_row17_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_202b9_row15_col5 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_202b9_row15_col6 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_202b9_row16_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_202b9_row16_col2 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_202b9_row16_col5 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_202b9_row16_col6 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_202b9_row17_col0, #T_202b9_row18_col6 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_202b9_row17_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_202b9_row17_col3, #T_202b9_row21_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_202b9_row17_col5 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_202b9_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_202b9_row18_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_202b9_row18_col2 {
#   background-color: #9

# %% [markdown]
# # Dropout 0.6 GraphConv

# %%
dropout = 0.6

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.6, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.6, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.6, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.6, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.6, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.6, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.6, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
# Train Acc: 0.2667 | Validation Acc: 0.1889
# Train F1: 0.2382 | Validation F1: 0.1406
#
# Epoch 18/30
# Train Loss: 1.6780 | Validation Loss: 1.7397
# Train Acc: 0.2500 | Validation Acc: 0.2444
# Train F1: 0.2095 | Validation F1: 0.1714
#
# Epoch 19/30
# Train Loss: 1.6816 | Validation Loss: 1.7412
# Train Acc: 0.2571 | Validation Acc: 0.2111
# Train F1: 0.2175 | Validation F1: 0.1391
#
# Epoch 20/30
# Train Loss: 1.6731 | Validation Loss: 1.7383
# Train Acc: 0.3000 | Validation Acc: 0.2111
# Train F1: 0.2589 | Validation F1: 0.1612
#
# Epoch 21/30
# Train Loss: 1.6478 | Validation Loss: 1.7351
# Train Acc: 0.2952 | Validation Acc: 0.2222
# Train F1: 0.2652 | Validation F1: 0.1574
#
# Epoch 22/30
# Train Loss: 1.6459 | Validation Loss: 1.7401
# Train Acc: 0.2952 | Validation Acc: 0.2111
# Train F1: 0.2467 | Validation F1: 0.1391
#
# Epoch 23/30
# Train Loss: 1.6383 | Validation Loss: 1.7359
# Train Acc: 0.2881 | Validation Acc: 0.2333
# Train F1: 0.2429 | Validation F1: 0.1657
#
# Epoch 24/30
# Train Loss: 1.6541 | Validation Loss: 1.7351
# Train Acc: 0.2905 | Validation Acc: 0.2444
# Train F1: 0.2466 | Validation F1: 0.1944
#
# Epoch 25/30
# Train Loss: 1.6542 | Validation Loss: 1.7364
# Train Acc: 0.2833 | Validation Acc: 0.2111
# Train F1: 0.2576 | Validation F1: 0.1607
#
# Epoch 26/30
# Train Loss: 1.6405 | Validation Loss: 1.7303
# Train Acc: 0.2833 | Validation Acc: 0.2333
# Train F1: 0.2563 | Validation F1: 0.1727
#
# Epoch 27/30
# Train Loss: 1.6275 | Validation Loss: 1.7274
# Train Acc: 0.3024 | Validation Acc: 0.2111
# Train F1: 0.2701 | Validation F1: 0.1398
#
# Epoch 28/30
# Train Loss: 1.6575 | Validation Loss: 1.7268
# Train Acc: 0.3000 | Validation Acc: 0.2111
# Train F1: 0.2700 | Validation F1: 0.1398
#
# Epoch 29/30
# Train Loss: 1.6396 | Validation Loss: 1.7269
# Train Acc: 0.3048 | Validation Acc: 0.2111
# Train F1: 0.2631 | Validation F1: 0.1398
#
# Epoch 30/30
# Train Loss: 1.6533 | Validation Loss: 1.7269
# Train Acc: 0.3048 | Validation Acc: 0.2111
# Train F1: 0.2727 | Validation F1: 0.1398

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_3fe71_row0_col0, #T_3fe71_row2_col6, #T_3fe71_row3_col6, #T_3fe71_row4_col3, #T_3fe71_row4_col5, #T_3fe71_row4_col6, #T_3fe71_row5_col6, #T_3fe71_row6_col6, #T_3fe71_row7_col4, #T_3fe71_row26_col1, #T_3fe71_row27_col2, #T_3fe71_row28_col2, #T_3fe71_row29_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_
{
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_3fe71_row15_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_3fe71_row15_col3, #T_3fe71_row17_col6 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_3fe71_row15_col5 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_3fe71_row15_col6 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_3fe71_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_3fe71_row16_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_3fe71_row16_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_3fe71_row16_col6 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_3fe71_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_3fe71_row17_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_3fe71_row17_col3 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_3fe71_row17_col4, #T_3fe71_row23_col4 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_3fe71_row17_col5 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_3fe71_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_3fe71_row18_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_3fe71_row18_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_3fe71_row18_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_3fe71_row18_col4, #T_3fe71_row19_col4, #T_3fe71_row21_col4, #T_3fe71_row24_col4, #T_3fe71_row26_col4, #T_3fe71_row27_col4, #T_3fe71_row28_col4, #T_3fe71_row29_col4 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_3fe71_row18_

# %% [markdown]
# # Dropout 0.7 GraphConv

# %%
dropout = 0.7

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.7, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.7, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.7, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.7, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.7, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.7, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.7, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7922 | Validation Loss: 1.7925
# Train Acc: 0.1762 | Validation Acc: 0.1667
# Train Acc: 0.2119 | Validation Acc: 0.2333
# Train F1: 0.1874 | Validation F1: 0.1495
#
# Epoch 19/30
# Train Loss: 1.7394 | Validation Loss: 1.7552
# Train Acc: 0.2357 | Validation Acc: 0.2333
# Train F1: 0.2115 | Validation F1: 0.1477
#
# Epoch 20/30
# Train Loss: 1.7429 | Validation Loss: 1.7520
# Train Acc: 0.2643 | Validation Acc: 0.2333
# Train F1: 0.2575 | Validation F1: 0.1512
#
# Epoch 21/30
# Train Loss: 1.7256 | Validation Loss: 1.7452
# Train Acc: 0.2333 | Validation Acc: 0.2222
# Train F1: 0.2153 | Validation F1: 0.1311
#
# Epoch 22/30
# Train Loss: 1.7328 | Validation Loss: 1.7423
# Train Acc: 0.2786 | Validation Acc: 0.2222
# Train F1: 0.2434 | Validation F1: 0.1278
#
# Epoch 23/30
# Train Loss: 1.7187 | Validation Loss: 1.7421
# Train Acc: 0.2476 | Validation Acc: 0.2444
# Train F1: 0.2106 | Validation F1: 0.1542
#
# Epoch 24/30
# Train Loss: 1.7216 | Validation Loss: 1.7424
# Train Acc: 0.2714 | Validation Acc: 0.2444
# Train F1: 0.2469 | Validation F1: 0.1533
#
# Epoch 25/30
# Train Loss: 1.7369 | Validation Loss: 1.7420
# Train Acc: 0.2333 | Validation Acc: 0.2333
# Train F1: 0.2202 | Validation F1: 0.1511
#
# Epoch 26/30
# Train Loss: 1.7186 | Validation Loss: 1.7418
# Train Acc: 0.2643 | Validation Acc: 0.2333
# Train F1: 0.2393 | Validation F1: 0.1511
#
# Epoch 27/30
# Train Loss: 1.7110 | Validation Loss: 1.7412
# Train Acc: 0.2548 | Validation Acc: 0.2333
# Train F1: 0.2245 | Validation F1: 0.1511
#
# Epoch 28/30
# Train Loss: 1.7276 | Validation Loss: 1.7410
# Train Acc: 0.2619 | Validation Acc: 0.2333
# Train F1: 0.2439 | Validation F1: 0.1511
#
# Epoch 29/30
# Train Loss: 1.7260 | Validation Loss: 1.7410
# Train Acc: 0.2714 | Validation Acc: 0.2333
# Train F1: 0.2422 | Validation F1: 0.1511
#
# Epoch 30/30
# Train Loss: 1.7162 | Validation Loss: 1.7410
# Train Acc: 0.2857 | Validation Acc: 0.2333
# Train F1: 0.2669 | Validation F1: 0.1511

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_2ef0e_row0_col0, #T_2ef0e_row2_col5, #T_2ef0e_row3_col6, #T_2ef0e_row4_col3, #T_2ef0e_row4_col6, #T_2ef0e_row5_col6, #T_2ef0e_row6_col6, #T_2ef0e_row7_col6, #T_2ef0e_row8_col4, #T_2ef0e_row9_col4, #T_2ef0e_row26_col1, #T_2ef0e_row26_col2, #T_2ef0e_row27_col2, #T_2ef0e_row28_col2, #T_2ef0e_row29_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2ef0e_row0_col1 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_2ef0e_row0_col2, #T_2ef0e_row1_col2, #T_2ef0e_row2_col1, #T_2ef0e_row2_col2, #T_2ef0e_row15_col6, #T_2ef0e_row22_col4, #T_2ef0e_row23_col4, #T_2ef0e_row29_col0, #T_2ef0e_row29_col3, #T_2ef0e_row29_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2ef0e_row0_col3, #T_2ef0e_row6_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_2ef0e_row0_col4, #T_2ef0e_row1_col4, #T_2ef0e_row2_col4, #T_2ef0e_row3_col4, #T_2ef0e_row4_col4, #T_2ef0e_row5_col4, #T_2ef0e_row6_col4, #T_2ef0e_row7_col4, #T_2ef0e_row10_col4, #T_2ef0e_row11_col4, #T_2ef0e_row13_col4 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_2ef0e_row0_col5, #T_2ef0e_row23_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_2ef0e_row0_col6, #T_2ef0e_row1_col6, #T_2ef0e_row2_col6 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_2ef0e_row1_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_2ef0e_row1_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_2ef0e_row1_col3, #T_2ef0e_row7_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_2ef0e_row1_col5 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_2ef0e_row2_col0, #T_2ef0e_row5_col3 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_2ef0e_row2_col3, #T_2ef0e_row9_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_2ef0e_row3_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_2ef0e_row3_col1, #T_2ef0e_row4_col2 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_2ef0e_row3_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_2ef0e_row3_col3, #T_2ef0e_row6_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_2ef0e_row3_col5, #T_2ef0e_row5_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_2ef0e_row4_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_2ef0e_row4_col1, #T_2ef0e_row22_col6 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_2ef0e_row4_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_2ef0e_row5_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_2ef0e_row5_col1, #T_2ef0e_row6_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_2ef0e_row5_col2 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_2ef0e_row6_col2, #T_2ef0e_row19_col6, #T_2ef0e_row24_col6, #T_2ef0e_row25_col6, #T_2ef0e_row26_col6, #T_2ef0e_row27_col6, #T_2ef0e_row28_col6, #T_2ef0e_row29_col6 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_2ef0e_row6_col5 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_2ef0e_row7_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_2ef0e_row7_col2, #T_2ef0e_row28_col5 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_2ef0e_row7_col3, #T_2ef0e_row11_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_2ef0e_row7_col5, #T_2ef0e_row27_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_2ef0e_row8_col0, #T_2ef0e_row18_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_2ef0e_row8_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_2ef0e_row8_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_2ef0e_row8_col3, #T_2ef0e_row14_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_2ef0e_row8_col5 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_2ef0e_row8_col6, #T_2ef0e_row9_col6, #T_2ef0e_row20_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_2ef0e_row9_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_2ef0e_row9_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_2ef0e_row9_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_2ef0e_row9_col5 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_2ef0e_row10_col0, #T_2ef0e_row18_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_2ef0e_row10_col1, #T_2ef0e_row21_col0, #T_2ef0e_row21_col6, #T_2ef0e_row22_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_2ef0e_row10_col2 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_2ef0e_row10_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_2ef0e_row10_col5 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_2ef0e_row10_col6, #T_2ef0e_row11_col6 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_2ef0e_row11_col1 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_2ef0e_row11_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_2ef0e_row11_col3, #T_2ef0e_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_2ef0e_row11_col5, #T_2ef0e_row12_col5, #T_2ef0e_row17_col2 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_2ef0e_row12_col0, #T_2ef0e_row13_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_2ef0e_row12_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_2ef0e_row12_col2 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_2ef0e_row12_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_2ef0e_row12_col4 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_2ef0e_row12_col6 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_2ef0e_row13_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_2ef0e_row13_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_2ef0e_row13_col2, #T_2ef0e_row18_col5 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_2ef0e_row13_col5 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_2ef0e_row13_col6, #T_2ef0e_row16_col5, #T_2ef0e_row19_col3, #T_2ef0e_row25_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_2ef0e_row14_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_2ef0e_row14_col2 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_2ef0e_row14_col4 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_2ef0e_row14_col5 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_2ef0e_row14_col6 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_2ef0e_row15_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_2ef0e_row15_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_2ef0e_row15_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_2ef0e_row15_col3, #T_2ef0e_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_2ef0e_row15_col4, #T_2ef0e_row16_col4, #T_2ef0e_row17_col4, #T_2ef0e_row18_col4, #T_2ef0e_row19_col4, #T_2ef0e_row24_col4, #T_2ef0e_row25_col4, #T_2ef0e_row26_col4, #T_2ef0e_row27_col4, #T_2ef0e_row28_col4, #T_2ef0e_row29_col4 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_2ef0e_row15_col5 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_2ef0e_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_2ef0e_row16_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_2ef0e_row16_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_2ef0e_row16_col3, #T_2ef0e_row25_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_2ef0e_row16_col6 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_2ef0e_row17_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_2ef0e_row17_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_2ef0e_row17_col5 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_2ef0e_row17_col6 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_2ef0e_row18_col0, #T_2ef0e_row20_col3, #T_2ef0e_row24_col3 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_2ef0e_row18_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_2ef0e_row18_col6 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_2ef0e_row19_col0, #T_2ef0e_row22_col5 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_2ef0e_row19_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_2ef0e_row19_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_2ef0e_row19_col5 {
#   background-color:

# %% [markdown]
# # Dropout 0.8 GraphConv

# %%
dropout = 0.8

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.8, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.8, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.8, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.8, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.8, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.8, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.8, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7933 | Validation Loss: 1.7925
# Train Acc: 0.1857 | Validation Acc: 0.1667
# Train F1: 0.1478 | Validation F1: 0.0476
#
# Epoch 2/30
# Train Loss: 1.7933 | Validation Loss: 1.7924
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.1280 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7932 | Validation Loss: 1.7923
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.1327 | Validation F1: 0.0476
#
# Epoch 4/30
# Train Loss: 1.7901 | Validation Loss: 1.7922
# Train Acc: 0.1833 | Validation Acc: 0.1667
# Train F1: 0.1611 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7915 | Validation Loss: 1.7920
# Train Acc: 0.1643 | Validation Acc: 0.1667
# Train F1: 0.1466 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7904 | Validation Loss: 1.7918
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.1515 | Validation F1: 0.0476
#
# Epoch 7/30
# Train Loss: 1.7917 | Validation Loss: 1.7912
# Train Acc: 0.1786 | Validation Acc: 0.1667
# Train F1: 0.1508 | Validation F1: 0.0476
#
# Epoch 8/30
# Train Loss: 1.7863 | Validation Loss: 1.7906
# Train Acc: 0.1643 | Validation Acc: 0.1667
# Train F1: 0.1329 | Validation F1: 0.0476
#
# Epoch 9/30
# Train Loss: 1.7832 | Validation Loss: 1.7896
# Train Acc: 0.1833 | Validation Acc: 0.1667
# Train F1: 0.1556 | Validation F1: 0.0476
#
# Epoch 10/30
# Train Loss: 1.7756 | Validation Loss: 1.7871
# Train Acc: 0.1571 | Validation Acc: 0.1667
# Train F1: 0.1334 | Validation F1: 0.0476
#
# Epoch 11/30
# Train Loss: 1.7755 | Validation Loss: 1.7852
# Train Acc: 0.2048 | Validation Acc: 0.1556
# Train F1: 0.1868 | Validation F1: 0.0814
#
# Epoch 12/30
# Train Loss: 1.7682 | Validation Loss: 1.7839
# Train Acc: 0.2071 | Validation Acc: 0.1667
# Train F1: 0.1883 | Validation F1: 0.0640
#
# Epoch 13/30
# Train Loss: 1.7693 | Validation Loss: 1.7842
# Train Acc: 0.2143 | Validation Acc: 0.1667
# Train F1: 0.1856 | Validation F1: 0.0640
#
# Epoch 14/30
# Train Loss: 1.7746 | Validation Loss: 1.7846
# Train Acc: 0.1905 | Validation Acc: 0.1667
# Train F1: 0.1662 | Validation F1: 0.0640
#
# Epoch 15/30
# Train Loss: 1.7746 | Validation Loss: 1.7847
# Train Acc: 0.1762 | Validation Acc: 0.1778
# Train F1: 0.1592 | Validation F1: 0.0832
#
# Epoch 16/30
# Train Loss: 1.7660 | Validation Loss: 1.7843
# Train Acc: 0.1905 | Validation Acc: 0.1667
# Train F1: 0.1638 | Validation F1: 0.0640
#
# Epoch 17/30
# Train Loss: 1.7674 | Validation Loss: 1.7833
# Train Acc: 0.2000 | Validation Acc: 0.1667
# Train F1: 0.1831 | Validation F1: 0.0640
#
# Epoch 18/30
# Train Loss: 1.7690 | Validation Loss: 1.7828
# Train Acc: 0.1881 | Validation Acc: 0.1667
# Train F1: 0.1654 | Validation F1: 0.0640
#
# Epoch 19/30
# Train Loss: 1.7619 | Validation Loss: 1.7829
# Train Acc: 0.2167 | Validation Acc: 0.1667
# Train F1: 0.1918 | Validation F1: 0.0640
#
# Epoch 20/30
# Train Loss: 1.7691 | Validation Loss: 1.7825
# Train Acc: 0.2119 | Validation Acc: 0.1667
# Train F1: 0.1898 | Validation F1: 0.0640
#
# Epoch 21/30
# Train Loss: 1.7774 | Validation Loss: 1.7828
# Train Acc: 0.1929 | Validation Acc: 0.2000
# Train F1: 0.1630 | Validation F1: 0.1144
#
# Epoch 22/30
# Train Loss: 1.7644 | Validation Loss: 1.7822
# Train Acc: 0.2310 | Validation Acc: 0.1889
# Train F1: 0.2062 | Validation F1: 0.0916
#
# Epoch 23/30
# Train Loss: 1.7636 | Validation Loss: 1.7818
# Train Acc: 0.2238 | Validation Acc: 0.1889
# Train F1: 0.1939 | Validation F1: 0.0916
#
# Epoch 24/30
# Train Loss: 1.7679 | Validation Loss: 1.7819
# Train Acc: 0.1833 | Validation Acc: 0.1889
# Train F1: 0.1587 | Validation F1: 0.0916
#
# Epoch 25/30
# Train Loss: 1.7722 | Validation Loss: 1.7818
# Train Acc: 0.1952 | Validation Acc: 0.1889
# Train F1: 0.1620 | Validation F1: 0.0916
#
# Epoch 26/30
# Train Loss: 1.7662 | Validation Loss: 1.7819
# Train Acc: 0.2071 | Validation Acc: 0.1889
# Train F1: 0.1791 | Validation F1: 0.0916
#
# Epoch 27/30
# Train Loss: 1.7614 | Validation Loss: 1.7818
# Train Acc: 0.2000 | Validation Acc: 0.1889
# Train F1: 0.1796 | Validation F1: 0.0916
#
# Epoch 28/30
# Train Loss: 1.7711 | Validation Loss: 1.7818
# Train Acc: 0.1643 | Validation Acc: 0.1889
# Train F1: 0.1529 | Validation F1: 0.0916
#
# Epoch 29/30
# Train Loss: 1.7660 | Validation Loss: 1.7818
# Train Acc: 0.2143 | Validation Acc: 0.1889
# Train F1: 0.1907 | Validation F1: 0.0916
#
# Epoch 30/30
# Train Loss: 1.7590 | Validation Loss: 1.7818
# Train Acc: 0.2429 | Validation Acc: 0.1889
# Train F1: 0.2012 | Validation F1: 0.0916

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
{
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_b4522_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_b4522_row12_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_b4522_row12_col2, #T_b4522_row14_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_b4522_row12_col3, #T_b4522_row28_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_b4522_row12_col5 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_b4522_row13_col0, #T_b4522_row20_col5 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_b4522_row13_col1, #T_b4522_row14_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_b4522_row13_col2, #T_b4522_row23_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_b4522_row13_col3, #T_b4522_row15_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_b4522_row13_col5 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_b4522_row14_col4, #T_b4522_row16_col3, #T_b4522_row26_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_b4522_row14_col5 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_b4522_row14_col6 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_b4522_row15_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_b4522_row15_col5 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_b4522_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_b4522_row16_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_b4522_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_b4522_row17_col2, #T_b4522_row20_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_b4522_row17_col3 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_b4522_row17_col5 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_b4522_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_b4522_row18_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_b4522_row18_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_b4522_row18_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_b4522_row18_col5 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_b4522_row19_col0, #T_b4522_row25_col5 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_b4522_row19_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_b4522_row19_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_b4522_row19_col5 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_b4522_row20_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_b4522_row20_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_b4522_row20_col3 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_b4522_row21_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_b4522_row21_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_b4522_row21_col2 {
#   background

# %% [markdown]
# # Dropout 0.9 GraphConv

# %%
dropout = 0.9

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.9, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.9, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.9, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.9, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.9, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.9, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.9, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.8142 | Validation Loss: 1.7925
# Train Acc: 0.1619 | Validation Acc: 0.1667
# Train F1: 0.1474 | Validation F1: 0.0476
#
# Epoch 2/30
# Train Loss: 1.8151 | Validation Loss: 1.7925
# Train Acc: 0.1643 | Validation Acc: 0.1667
# Train F1: 0.1441 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7916 | Validation Loss: 1.7924
# Train Acc: 0.1857 | Validation Acc: 0.1667
# Train F1: 0.1758 | Validation F1: 0.0476
#
# Epoch 4/30
# Train Loss: 1.8084 | Validation Loss: 1.7924
# Train Acc: 0.1643 | Validation Acc: 0.1667
# Train F1: 0.1609 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.8034 | Validation Loss: 1.7922
# Train Acc: 0.1619 | Validation Acc: 0.1667
# Train F1: 0.1584 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7943 | Validation Loss: 1.7921
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.1685 | Validation F1: 0.0476
#
# Epoch 7/30
# Train Loss: 1.8125 | Validation Loss: 1.7919
# Train Acc: 0.1381 | Validation Acc: 0.1667
# Train F1: 0.1318 | Validation F1: 0.0476
#
# Epoch 8/30
# Train Loss: 1.8060 | Validation Loss: 1.7918
# Train Acc: 0.1595 | Validation Acc: 0.1667
# Train F1: 0.1526 | Validation F1: 0.0476
#
# Epoch 9/30
# Train Loss: 1.8048 | Validation Loss: 1.7917
# Train Acc: 0.1571 | Validation Acc: 0.1667
# Train F1: 0.1566 | Validation F1: 0.0476
#
# Epoch 10/30
# Train Loss: 1.7834 | Validation Loss: 1.7916
# Train Acc: 0.1905 | Validation Acc: 0.1667
# Train F1: 0.1870 | Validation F1: 0.0476
#
# Epoch 11/30
# Train Loss: 1.7936 | Validation Loss: 1.7915
# Train Acc: 0.1833 | Validation Acc: 0.1667
# Train F1: 0.1765 | Validation F1: 0.0476
#
# Epoch 12/30
# Train Loss: 1.7869 | Validation Loss: 1.7913
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.1636 | Validation F1: 0.0476
#
# Epoch 13/30
# Train Loss: 1.7984 | Validation Loss: 1.7913
# Train Acc: 0.1595 | Validation Acc: 0.1667
# Train F1: 0.1593 | Validation F1: 0.0476
#
# Epoch 14/30
# Train Loss: 1.7923 | Validation Loss: 1.7911
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.1703 | Validation F1: 0.0476
#
# Epoch 15/30
# Train Loss: 1.7930 | Validation Loss: 1.7910
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.1704 | Validation F1: 0.0476
#
# Epoch 16/30
# Train Loss: 1.7740 | Validation Loss: 1.7909
# Train Acc: 0.2095 | Validation Acc: 0.1667
# Train F1: 0.2100 | Validation F1: 0.0476
#
# Epoch 17/30
# Train Loss: 1.7975 | Validation Loss: 1.7908
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.1688 | Validation F1: 0.0476
#
# Epoch 18/30
# Train Loss: 1.7906 | Validation Loss: 1.7908
# Train Acc: 0.1786 | Validation Acc: 0.1667
# Train F1: 0.1731 | Validation F1: 0.0476
#
# Epoch 19/30
# Train Loss: 1.7875 | Validation Loss: 1.7908
# Train Acc: 0.1952 | Validation Acc: 0.1556
# Train F1: 0.1933 | Validation F1: 0.0458
#
# Epoch 20/30
# Train Loss: 1.7901 | Validation Loss: 1.7908
# Train Acc: 0.1286 | Validation Acc: 0.1556
# Train F1: 0.1276 | Validation F1: 0.0458
#
# Epoch 21/30
# Train Loss: 1.7813 | Validation Loss: 1.7907
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.1722 | Validation F1: 0.0481
#
# Epoch 22/30
# Train Loss: 1.7821 | Validation Loss: 1.7907
# Train Acc: 0.2262 | Validation Acc: 0.1667
# Train F1: 0.2192 | Validation F1: 0.0476
#
# Epoch 23/30
# Train Loss: 1.7798 | Validation Loss: 1.7906
# Train Acc: 0.2071 | Validation Acc: 0.1667
# Train F1: 0.2066 | Validation F1: 0.0476
#
# Epoch 24/30
# Train Loss: 1.7820 | Validation Loss: 1.7906
# Train Acc: 0.1762 | Validation Acc: 0.1667
# Train F1: 0.1762 | Validation F1: 0.0476
#
# Epoch 25/30
# Train Loss: 1.7916 | Validation Loss: 1.7906
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.1665 | Validation F1: 0.0476
#
# Epoch 26/30
# Train Loss: 1.7798 | Validation Loss: 1.7906
# Train Acc: 0.2048 | Validation Acc: 0.1667
# Train F1: 0.2015 | Validation F1: 0.0476
#
# Epoch 27/30
# Train Loss: 1.7853 | Validation Loss: 1.7906
# Train Acc: 0.1952 | Validation Acc: 0.1667
# Train F1: 0.1904 | Validation F1: 0.0476
#
# Epoch 28/30
# Train Loss: 1.7893 | Validation Loss: 1.7906
# Train Acc: 0.1476 | Validation Acc: 0.1667
# Train F1: 0.1469 | Validation F1: 0.0476
#
# Epoch 29/30
# Train Loss: 1.7840 | Validation Loss: 1.7906
# Train Acc: 0.1976 | Validation Acc: 0.1667
# Train F1: 0.1963 | Validation F1: 0.0476
#
# Epoch 30/30
# Train Loss: 1.7752 | Validation Loss: 1.7906
# Train Acc: 0.1833 | Validation Acc: 0.1667
# Train F1: 0.1798 | Validation F1: 0.0476

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_bf774_row0_col0, #T_bf774_row15_col1, #T_bf774_row18_col4, #T_bf774_row18_col6, #T_bf774_row19_col3, #T_bf774_row19_col4, #T_bf774_row19_col5, #T_bf774_row19_col6, #T_bf774_row26_col2, #T_bf774_row27_col2, #T_bf774_row28_col2, #T_bf774_row29_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bf774_row0_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_bf774_row0_col2, #T_bf774_row0_col4, #T_bf774_row1_col1, #T_bf774_row1_col4, #T_bf774_row2_col4, #T_bf774_row3_col4, #T_bf774_row4_col4, #T_bf774_row5_col4, #T_bf774_row6_col4, #T_bf774_row7_col4, #T_bf774_row8_col4, #T_bf774_row9_col4, #T_bf774_row10_col4, #T_bf774_row11_col4, #T_bf774_row12_col4, #T_bf774_row13_col4, #T_bf774_row14_col4, #T_bf774_row15_col4, #T_bf774_row16_col4, #T_bf774_row17_col4, #T_bf774_row20_col4, #T_bf774_row20_col6, #T_bf774_row21_col3, #T_bf774_row21_col4, #T_bf774_row21_col5, #T_bf774_row22_col4, #T_bf774_row23_col4, #T_bf774_row24_col4, #T_bf774_row25_col4, #T_bf774_row26_col4, #T_bf774_row27_col4, #T_bf774_row28_col4, #T_bf774_row29_col0, #T_bf774_row29_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bf774_row0_col3, #T_bf774_row4_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_bf774_row0_col5 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_bf774_row0_col6, #T_bf774_row1_col6, #T_bf774_row2_col6, #T_bf774_row3_col6, #T_bf774_row4_col6, #T_bf774_row5_col6, #T_bf774_row6_col6, #T_bf774_row7_col6, #T_bf774_row8_col6, #T_bf774_row9_col6, #T_bf774_row10_col6, #T_bf774_row11_col6, #T_bf774_row12_col6, #T_bf774_row13_col6, #T_bf774_row14_col6, #T_bf774_row15_col6, #T_bf774_row16_col6, #T_bf774_row17_col6, #T_bf774_row21_col6, #T_bf774_row22_col6, #T_bf774_row23_col6, #T_bf774_row24_col6, #T_bf774_row25_col6, #T_bf774_row26_col6, #T_bf774_row27_col6, #T_bf774_row28_col6, #T_bf774_row29_col6 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_bf774_row1_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_bf774_row1_col2 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_bf774_row1_col3, #T_bf774_row3_col3, #T_bf774_row3_col5, #T_bf774_row12_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_bf774_row1_col5, #T_bf774_row15_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_bf774_row2_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_bf774_row2_col1, #T_bf774_row24_col1 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_bf774_row2_col2 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_bf774_row2_col3 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_bf774_row2_col5 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_bf774_row3_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_bf774_row3_col1 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_bf774_row3_col2 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_bf774_row4_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_bf774_row4_col1, #T_bf774_row18_col5 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_bf774_row4_col2 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_bf774_row4_col5 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_bf774_row5_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_bf774_row5_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_bf774_row5_col2, #T_bf774_row22_col3, #T_bf774_row25_col5 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_bf774_row5_col3, #T_bf774_row13_col3, #T_bf774_row16_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_bf774_row5_col5, #T_bf774_row13_col0, #T_bf774_row13_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_bf774_row6_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_bf774_row6_col1 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_bf774_row6_col2 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_bf774_row6_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_bf774_row6_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_bf774_row7_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_bf774_row7_col1, #T_bf774_row25_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_bf774_row7_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_bf774_row7_col3, #T_bf774_row8_col5, #T_bf774_row12_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_bf774_row7_col5 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_bf774_row8_col0, #T_bf774_row26_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_bf774_row8_col1, #T_bf774_row28_col5 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_bf774_row8_col2, #T_bf774_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_bf774_row8_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_bf774_row9_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_bf774_row9_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_bf774_row9_col2, #T_bf774_row17_col3 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_bf774_row9_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_bf774_row9_col5 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_bf774_row10_col0, #T_bf774_row12_col5 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_bf774_row10_col1 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_bf774_row10_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_bf774_row10_col3, #T_bf774_row29_col3 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_bf774_row10_col5 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_bf774_row11_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_bf774_row11_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_bf774_row11_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_bf774_row11_col3, #T_bf774_row24_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_bf774_row11_col5, #T_bf774_row19_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_bf774_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_bf774_row12_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_bf774_row13_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_bf774_row13_col5, #T_bf774_row14_col5 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_bf774_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_bf774_row14_col1, #T_bf774_row14_col3 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_bf774_row14_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_bf774_row15_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_bf774_row15_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_bf774_row15_col5 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_bf774_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_bf774_row16_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_bf774_row16_col2, #T_bf774_row18_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_bf774_row16_col5 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_bf774_row17_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_bf774_row17_col2, #T_bf774_row19_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_bf774_row17_col5 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_bf774_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_bf774_row18_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_bf774_row18_col3, #T_bf774_row26_col3 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_bf774_row19_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_bf774_row20_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_bf774_row20_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_bf774_row20_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_bf774_row20_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_bf774_row20_col5, #T_bf774_row23_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_bf774_row21_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_bf774_row21_col1 {
#   background-color: #d0e2f2;

# %% [markdown]
# # Dropout 1.0 GraphConv

# %%
dropout = 1.0

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=1.0, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=1.0, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=1.0, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=1.0, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=1.0, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=1.0, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=1.0, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 2/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 4/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 7/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 8/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 9/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 10/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 11/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 12/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 13/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 14/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 15/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 16/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 17/30
# Train Loss: 1.7920 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 18/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 19/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 20/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 21/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 22/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 23/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 24/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 25/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 26/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 27/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 28/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 29/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476
#
# Epoch 30/30
# Train Loss: 1.7919 | Validation Loss: 1.7926
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0476 | Validation F1: 0.0476

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_77599_row0_col0, #T_77599_row0_col3, #T_77599_row0_col4, #T_77599_row0_col5, #T_77599_row0_col6, #T_77599_row1_col3, #T_77599_row1_col4, #T_77599_row1_col5, #T_77599_row1_col6, #T_77599_row2_col3, #T_77599_row2_col4, #T_77599_row2_col5, #T_77599_row2_col6, #T_77599_row3_col3, #T_77599_row3_col4, #T_77599_row3_col5, #T_77599_row3_col6, #T_77599_row4_col3, #T_77599_row4_col4, #T_77599_row4_col5, #T_77599_row4_col6, #T_77599_row5_col3, #T_77599_row5_col4, #T_77599_row5_col5, #T_77599_row5_col6, #T_77599_row6_col3, #T_77599_row6_col4, #T_77599_row6_col5, #T_77599_row6_col6, #T_77599_row7_col3, #T_77599_row7_col4, #T_77599_row7_col5, #T_77599_row7_col6, #T_77599_row8_col3, #T_77599_row8_col4, #T_77599_row8_col5, #T_77599_row8_col6, #T_77599_row9_col3, #T_77599_row9_col4, #T_77599_row9_col5, #T_77599_row9_col6, #T_77599_row10_col3, #T_77599_row10_col4, #T_77599_row10_col5, #T_77599_row10_col6, #T_77599_row11_col3, #T_77599_row11_col4, #T_77599_row11_col5, #T_77599_row11_col6, #T_77599_row12_col3, #T_77599_row12_col4, #T_77599_row12_col5, #T_77599_row12_col6, #T_77599_row13_col3, #T_77599_row13_col4, #T_77599_row13_col5, #T_77599_row13_col6, #T_77599_row14_col3, #T_77599_row14_col4, #T_77599_row14_col5, #T_77599_row14_col6, #T_77599_row15_col3, #T_77599_row15_col4, #T_77599_row15_col5, #T_77599_row15_col6, #T_77599_row16_col3, #T_77599_row16_col4, #T_77599_row16_col5, #T_77599_row16_col6, #T_77599_row17_col3, #T_77599_row17_col4, #T_77599_row17_col5, #T_77599_row17_col6, #T_77599_row18_col3, #T_77599_row18_col4, #T_77599_row18_col5