# %%
from tools.utils import *
from tools.het_networks import *

import torch

from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader

from sklearn.model_selection import train_test_split

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random
seed = 42

# Model
hidden_channels = 128
num_classes = 6
num_layers = 2
intra_aggr='mean'
inter_aggr='sum'
dropout = 0.5 # Validated choice in experiment 2

# Training
batch_size = 32
epochs = 30
lr = 1e-4
maxlr = 3e-4

# %% [markdown]
# # Preprocessing

# %%
# Load the ENZYMES dataset
hom_dataset = TUDataset(root='data', name='ENZYMES')                          # This has 3 one-hot encodings
hom_dataset_attr = TUDataset(root='data', name='ENZYMES', use_node_attr=True) # This has 3 one-hot encodings and 18 features

# %%
def normalize_enzymes_data(data):
    data = data.clone()
    if hasattr(data, 'x') and data.x is not None:
        x = data.x
        feats = x[:, :18]
        mean = feats.mean(dim=0)
        std = feats.std(dim=0, unbiased=False)
        std[std == 0] = 1.0
        normalized_feats = (feats - mean) / std
        x[:, :18] = normalized_feats
        data.x = x
    return data

# Normalize features
normalized_hom_dataset_attr = [normalize_enzymes_data(hom_data) for hom_data in hom_dataset_attr]

# %%
# Construct het dataset
het_dataset = []
for hom_data in normalized_hom_dataset_attr:
    het_data = convert_hom_to_het(hom_data, onehot_indices=[18, 19, 20], is_directed=False)
    het_dataset.append(het_data)
het_dataset.__len__()
# Out:
# 600

# %%
# Get the metadata to build HeteroGNN
edge_types = het_dataset[0].edge_types
node_types = het_dataset[0].node_types
metadata = (node_types, edge_types)
metadata
# Out:
# (['A', 'B', 'C'],
#  [('A', 'edge_index', 'A'),
#   ('A', 'edge_index', 'B'),
#   ('A', 'edge_index', 'C'),
#   ('B', 'edge_index', 'B'),
#   ('B', 'edge_index', 'C'),
#   ('C', 'edge_index', 'C')])

# %%
# Create splits
labels = [data.y.item() for data in het_dataset]

train_set, temp_set = train_test_split(
    het_dataset, 
    test_size=0.3, 
    stratify=labels,
    random_state=seed
    
)

temp_labels = [data.y.item() for data in temp_set]
valid_set, test_set = train_test_split(
    temp_set, 
    test_size=0.5, 
    stratify=temp_labels,
    random_state=seed
)

# train_loader is defined at each experiment for reproducibility
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Weight decay 1e-4 GraphConv

# %%
decay = 1e-4

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-{decay} decay-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7928 | Validation Loss: 1.7924
# Train Acc: 0.1333 | Validation Acc: 0.1667
# Train F1: 0.0745 | Validation F1: 0.0481
#
# Epoch 2/30
# Train Loss: 1.7922 | Validation Loss: 1.7923
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.1055 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7923 | Validation Loss: 1.7921
# Train Acc: 0.1833 | Validation Acc: 0.1667
# Train F1: 0.1080 | Validation F1: 0.0495
#
# Epoch 4/30
# Train Loss: 1.7915 | Validation Loss: 1.7917
#
# Epoch 21/30
# Train Loss: 1.5966 | Validation Loss: 1.7017
# Train Acc: 0.3262 | Validation Acc: 0.2111
# Train F1: 0.2985 | Validation F1: 0.1561
#
# Epoch 22/30
# Train Loss: 1.5823 | Validation Loss: 1.6961
# Train Acc: 0.3357 | Validation Acc: 0.2333
# Train F1: 0.2842 | Validation F1: 0.1821
#
# Epoch 23/30
# Train Loss: 1.5748 | Validation Loss: 1.6893
# Train Acc: 0.3452 | Validation Acc: 0.2444
# Train F1: 0.3025 | Validation F1: 0.1994
#
# Epoch 24/30
# Train Loss: 1.5680 | Validation Loss: 1.6836
# Train Acc: 0.3262 | Validation Acc: 0.2444
# Train F1: 0.2927 | Validation F1: 0.2020
#
# Epoch 25/30
# Train Loss: 1.5741 | Validation Loss: 1.6812
# Train Acc: 0.3405 | Validation Acc: 0.2333
# Train F1: 0.3163 | Validation F1: 0.1803
#
# Epoch 26/30
# Train Loss: 1.5656 | Validation Loss: 1.6738
# Train Acc: 0.3143 | Validation Acc: 0.2556
# Train F1: 0.2903 | Validation F1: 0.2128
#
# Epoch 27/30
# Train Loss: 1.5469 | Validation Loss: 1.6729
# Train Acc: 0.3643 | Validation Acc: 0.2556
# Train F1: 0.3423 | Validation F1: 0.2058
#
# Epoch 28/30
# Train Loss: 1.5569 | Validation Loss: 1.6731
# Train Acc: 0.3571 | Validation Acc: 0.2556
# Train F1: 0.3325 | Validation F1: 0.2065
#
# Epoch 29/30
# Train Loss: 1.5488 | Validation Loss: 1.6727
# Train Acc: 0.3524 | Validation Acc: 0.2556
# Train F1: 0.3270 | Validation F1: 0.2065
#
# Epoch 30/30
# Train Loss: 1.5595 | Validation Loss: 1.6726
# Train Acc: 0.3405 | Validation Acc: 0.2556
# Train F1: 0.3064 | Validation F1: 0.2065

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_22cad_row0_col0, #T_22cad_row0_col3, #T_22cad_row0_col5, #T_22cad_row0_col6, #T_22cad_row1_col6, #T_22cad_row3_col6, #T_22cad_row4_col6, #T_22cad_row6_col4, #T_22cad_row7_col4, #T_22cad_row26_col1, #T_22cad_row26_col2, #T_22cad_row28_col2, #T_22cad_row29_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_22cad_row0_col1, #T_22cad_row0_col2, #T_22cad_row1_col1, #T_22cad_row1_col2, #T_22cad_row2_col1, #T_22cad_row2_col2, #T_22cad_row11_col4, #T_22cad_row13_col4, #T_22cad_row25_col4, #T_22cad_row25_col6, #T_22cad_row26_col3, #T_22cad_row26_col4, #T_22cad_row26_col5, #T_22cad_row27_col4, #T_22cad_row28_col4, #T_22cad_row29_col0, #T_22cad_row29_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_22cad_row0_col4, #T_22cad_row1_col4, #T_22cad_row2_col4, #T_22cad_row3_col4, #T_22cad_row4_col4, #T_22cad_row20_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_22cad_row1_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_22cad_row1_col3, #T_22cad_row3_col3, #T_22cad_row5_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T
{
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_22cad_row17_col2, #T_22cad_row18_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_22cad_row17_col5 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_22cad_row17_col6 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_22cad_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_22cad_row18_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_22cad_row19_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_22cad_row19_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_22cad_row19_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_22cad_row19_col3 {
#   background-color: #0e58a2;
#   co

# %% [markdown]
# # Weight decay 5e-4 GraphConv

# %%
decay = 5e-4

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-{decay} decay-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7928 | Validation Loss: 1.7924
# Train Acc: 0.1333 | Validation Acc: 0.1667
# Train F1: 0.0745 | Validation F1: 0.0481
#
# Epoch 2/30
# Train Loss: 1.7922 | Validation Loss: 1.7924
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.1043 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7923 | Validation Loss: 1.7921
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.1063 | Validation F1: 0.0490
#
# Epoch 4/30
# Train Loss: 1.7917 | Validation Loss: 1.7918
# Train Acc: 0.1762 | Validation Acc: 0.1667
# Train F1: 0.1124 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7915 | Validation Loss: 1.7912
# Train Acc: 0.1643 | Validation Acc: 0.1667
# Train F1: 0.0760 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7895 | Validation Loss: 1.7904
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.1014 | Validation F1: 0.0481
#
# Epoch 7/30
# Train Loss: 1.7880 | Validation Loss: 1.7868
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.1024 | Validation F1: 0.0476
#
# Epoch 8/30
# Train Loss: 1.7772 | Validation Loss: 1.7828
# Train Acc: 0.1762 | Validation Acc: 0.1444
# Train F1: 0.0809 | Validation F1: 0.0563
#
# Epoch 9/30
# Train Loss: 1.7710 | Validation Loss: 1.7855
# Train Acc: 0.1810 | Validation Acc: 0.1444
# Train F1: 0.0899 | Validation F1: 0.0563
#
# Epoch 10/30
# Train Loss: 1.7668 | Validation Loss: 1.7814
# Train Acc: 0.2071 | Validation Acc: 0.1667
# Train F1: 0.1502 | Validation F1: 0.0929
#
# Epoch 11/30
# Train Loss: 1.7658 | Validation Loss: 1.7789
# Train Acc: 0.2048 | Validation Acc: 0.1667
# Train F1: 0.1525 | Validation F1: 0.0640
#
# Epoch 12/30
# Train Loss: 1.7588 | Validation Loss: 1.7730
# Train Acc: 0.2071 | Validation Acc: 0.1667
# Train F1: 0.1402 | Validation F1: 0.0988
#
# Epoch 13/30
# Train Loss: 1.7515 | Validation Loss: 1.7732
# Train Acc: 0.2143 | Validation Acc: 0.1778
# Train F1: 0.1821 | Validation F1: 0.1211
#
# Epoch 14/30
# Train Loss: 1.7442 | Validation Loss: 1.7617
# Train Acc: 0.2381 | Validation Acc: 0.2333
# Train F1: 0.1983 | Validation F1: 0.1450
#
# Epoch 15/30
# Train Loss: 1.7170 | Validation Loss: 1.7590
# Train Acc: 0.2595 | Validation Acc: 0.2222
# Train F1: 0.1840 | Validation F1: 0.1446
#
# Epoch 16/30
# Train Loss: 1.6957 | Validation Loss: 1.7556
# Train Acc: 0.2643 | Validation Acc: 0.2000
# Train F1: 0.1991 | Validation F1: 0.1226
#
# Epoch 17/30
# Train Loss: 1.6744 | Validation Loss: 1.7522
# Train Acc: 0.2857 | Validation Acc: 0.1889
# Train F1: 0.2487 | Validation F1: 0.1482
#
# Epoch 18/30
# Train Loss: 1.6674 | Validation Loss: 1.7407
# Train Acc: 0.2548 | Validation Acc: 0.2111
# Train F1: 0.2131 | Validation F1: 0.1394
#
# Epoch 19/30
# Train Loss: 1.6610 | Validation Loss: 1.7397
# Train Acc: 0.2786 | Validation Acc: 0.2111
# Train F1: 0.2357 | Validation F1: 0.1411
#
# Epoch 20/30
# Train Loss: 1.6548 | Validation Loss: 1.7325
# Train Acc: 0.3190 | Validation Acc: 0.2222
# Train F1: 0.2720 | Validation F1: 0.1590
#
# Epoch 21/30
# Train Loss: 1.6380 | Validation Loss: 1.7312
# Train Acc: 0.2976 | Validation Acc: 0.2222
# Train F1: 0.2573 | Validation F1: 0.1571
#
# Epoch 22/30
# Train Loss: 1.6299 | Validation Loss: 1.7333
# Train Acc: 0.3357 | Validation Acc: 0.2222
# Train F1: 0.2785 | Validation F1: 0.1579
#
# Epoch 23/30
# Train Loss: 1.6285 | Validation Loss: 1.7286
# Train Acc: 0.3167 | Validation Acc: 0.2333
# Train F1: 0.2746 | Validation F1: 0.1812
#
# Epoch 24/30
# Train Loss: 1.6255 | Validation Loss: 1.7216
# Train Acc: 0.3143 | Validation Acc: 0.2222
# Train F1: 0.2649 | Validation F1: 0.1607
#
# Epoch 25/30
# Train Loss: 1.6246 | Validation Loss: 1.7217
# Train Acc: 0.3190 | Validation Acc: 0.2111
# Train F1: 0.2802 | Validation F1: 0.1549
#
# Epoch 26/30
# Train Loss: 1.6243 | Validation Loss: 1.7166
# Train Acc: 0.3071 | Validation Acc: 0.2222
# Train F1: 0.2624 | Validation F1: 0.1609
#
# Epoch 27/30
# Train Loss: 1.6037 | Validation Loss: 1.7159
# Train Acc: 0.3381 | Validation Acc: 0.2222
# Train F1: 0.3035 | Validation F1: 0.1593
#
# Epoch 28/30
# Train Loss: 1.6156 | Validation Loss: 1.7163
# Train Acc: 0.3190 | Validation Acc: 0.2333
# Train F1: 0.2781 | Validation F1: 0.1636
#
# Epoch 29/30
# Train Loss: 1.6109 | Validation Loss: 1.7163
# Train Acc: 0.3095 | Validation Acc: 0.2333
# Train F1: 0.2657 | Validation F1: 0.1636
#
# Epoch 30/30
# Train Loss: 1.6203 | Validation Loss: 1.7163
# Train Acc: 0.3238 | Validation Acc: 0.2333
# Train F1: 0.2774 | Validation F1: 0.1645

# %%
{
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_1de8d_row9_col2 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_1de8d_row9_col3, #T_1de8d_row11_col3 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_1de8d_row9_col5 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_1de8d_row9_col6, #T_1de8d_row17_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_1de8d_row10_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_1de8d_row10_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_1de8d_row10_col2, #T_1de8d_row25_col5 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_1de8d_row10_col3 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_1de8d_row10_col5 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_1de8d_row11_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_1de8d_row11_col1, #T_1de8d_row20_col6 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_1de8d_row11_col2, #T_1de8d_row12_col2 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_1de8d_row11_col5 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_1de8d_row11_col6 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_1de8d_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_1de8d_row12_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_1de8d_row12_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_1de8d_row12_col4 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_1de8d_row12_col5 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_1de8d_row12_col6 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_1de8d_row13_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_1de8d_row13_col1, #T_1de8d_row16_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_1de8d_row13_col2, #T_1de8d_row14_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_1de8d_row13_col3 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_1de8d_row13_col5 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_1de8d_row13_col6 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_1de8d_row14_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_1de8d_row14_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_1de8d_row14_col3 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_1de8d_row14_col5 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_1de8d_row14_col6, #T_1de8d_row21_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_1de8d_row15_col0, #T_1de8d_row15_col2 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_1de8d_row15_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_1de8d_row15_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_1de8d_row15_col4 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_1de8d_row15_col5 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_1de8d_row15_col6 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_1de8d_row16_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_1de8d_row16_col1 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_1de8d_row16_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_1de8d_row16_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_1de8d_row16_col5, #T_1de8d_row22_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_1de8d_row16_col6, #T_1de8d_row17_col4, #T_1de8d_row18_col4, #T_1de8d_row24_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_1de8d_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_1de8d_row17_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_1de8d_row17_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_1de8d_row17_col5 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_1de8d_row17_col6 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_1de8d_row18_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_1de8d_row18_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_1de8d_row18_col3 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_1de8d_row18_col5 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_1de8d_row18_col6 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_1de8d_row19_col0 {
#   background-color: #3a8ac2;
#   color: #f1

# %% [markdown]
# # Weight decay 1e-3 GraphConv

# %%
decay = 1e-3

# %%
experiment_name = f"ENZYMES-HeteroGNN_GraphConv-{hidden_channels} hidden channels-{num_layers} mlp-{num_layers} conv-{intra_aggr} intra_aggr-{inter_aggr} inter_aggr-{dropout} dropout-{lr} lr-{maxlr} maxlr-{decay} decay-OneCylceLR-Adam-CE Loss"

reset_seeds(seed, device)
train_loader = get_train_loader(seed, train_set, batch_size)
model = HeteroGNN_GraphConv(metadata, hidden_channels, num_classes, mlp_layers=num_layers, conv_layers=num_layers, intra_aggr=intra_aggr, inter_aggr=inter_aggr, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay)
criterion = torch.nn.CrossEntropyLoss()
model
# Out:
# HeteroGNN_GraphConv(
#   (node_emb_layers): ModuleDict(
#     (A): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (B): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#     (C): MLP(
#       (layers): ModuleList(
#         (0): Linear(-1, 128, bias=True)
#         (1): Dropout(p=0.5, inplace=False)
#         (2): Linear(128, 128, bias=True)
#       )
#     )
#   )
#   (conv_blocks): ModuleList(
#     (0-1): 2 x ModuleDict(
#       (conv): HeteroConv(num_relations=6)
#       (post_lin): ModuleDict(
#         (A): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (B): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#         (C): MLP(
#           (layers): ModuleList(
#             (0): Linear(-1, 128, bias=True)
#             (1): Dropout(p=0.5, inplace=False)
#             (2): Linear(128, 128, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Linear(384, 6, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
batches_per_epoch = len(train_loader)
total_steps = epochs * batches_per_epoch

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=maxlr, total_steps=total_steps, epochs=epochs, cycle_momentum=False)

# %%
metrics = {
    'train_loss': [],
    'valid_loss': [],
    'train_acc': [],
    'valid_acc': [],
    'train_f1': [],
    'valid_f1': []
}

for epoch in range(1, epochs+1):
    train_loss, train_acc, train_f1 = train(model, train_loader, optimizer, criterion, het_predict, scheduler=scheduler, device=device)
    valid_loss, valid_acc, valid_f1 = test(model, valid_loader, criterion, het_predict, device=device)
    
    # Update metrics
    metrics['train_loss'].append(train_loss)
    metrics['valid_loss'].append(valid_loss)
    metrics['train_acc'].append(train_acc)
    metrics['valid_acc'].append(valid_acc)
    metrics['train_f1'].append(train_f1)
    metrics['valid_f1'].append(valid_f1)
    
    print(f"Epoch {epoch}/{epochs}")
    print(f"Train Loss: {train_loss:.4f} | Validation Loss: {valid_loss:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Validation Acc: {valid_acc:.4f}")
    print(f"Train F1: {train_f1:.4f} | Validation F1: {valid_f1:.4f}\n")
# Out:
# Epoch 1/30
# Train Loss: 1.7928 | Validation Loss: 1.7925
# Train Acc: 0.1333 | Validation Acc: 0.1667
# Train F1: 0.0745 | Validation F1: 0.0481
#
# Epoch 2/30
# Train Loss: 1.7922 | Validation Loss: 1.7924
# Train Acc: 0.1690 | Validation Acc: 0.1667
# Train F1: 0.1031 | Validation F1: 0.0476
#
# Epoch 3/30
# Train Loss: 1.7924 | Validation Loss: 1.7922
# Train Acc: 0.1833 | Validation Acc: 0.1667
# Train F1: 0.1103 | Validation F1: 0.0490
#
# Epoch 4/30
# Train Loss: 1.7918 | Validation Loss: 1.7919
# Train Acc: 0.1738 | Validation Acc: 0.1667
# Train F1: 0.1110 | Validation F1: 0.0476
#
# Epoch 5/30
# Train Loss: 1.7917 | Validation Loss: 1.7915
# Train Acc: 0.1667 | Validation Acc: 0.1667
# Train F1: 0.0808 | Validation F1: 0.0476
#
# Epoch 6/30
# Train Loss: 1.7902 | Validation Loss: 1.7910
# Train Acc: 0.1714 | Validation Acc: 0.1667
# Train F1: 0.0966 | Validation F1: 0.0476
#
# Epoch 7/30
# Train Loss: 1.7900 | Validation Loss: 1.7899
# Train Acc: 0.1810 | Validation Acc: 0.1667
# Train F1: 0.0959 | Validation F1: 0.0476
#
# Epoch 8/30
# Train Loss: 1.7875 | Validation Loss: 1.7881
# Train Acc: 0.1643 | Validation Acc: 0.1667
# Train F1: 0.0477 | Validation F1: 0.0476
#
# Epoch 9/30
# Train Loss: 1.7811 | Validation Loss: 1.7840
# Train Acc: 0.1762 | Validation Acc: 0.1444
# Train F1: 0.0787 | Validation F1: 0.0563
#
# Epoch 10/30
# Train Loss: 1.7728 | Validation Loss: 1.7866
# Train Acc: 0.1738 | Validation Acc: 0.1444
# Train F1: 0.0798 | Validation F1: 0.0563
#
# Epoch 11/30
# Train Loss: 1.7702 | Validation Loss: 1.7820
# Train Acc: 0.2071 | Validation Acc: 0.1667
# Train F1: 0.1511 | Validation F1: 0.0640
#
# Epoch 12/30
# Train Loss: 1.7677 | Validation Loss: 1.7803
# Train Acc: 0.1905 | Validation Acc: 0.1667
# Train F1: 0.0945 | Validation F1: 0.0640
#
# Epoch 13/30
# Train Loss: 1.7669 | Validation Loss: 1.7857
# Train Acc: 0.1905 | Validation Acc: 0.1667
# Train F1: 0.0945 | Validation F1: 0.0640
#
# Epoch 14/30
# Train Loss: 1.7679 | Validation Loss: 1.7791
# Train Acc: 0.1929 | Validation Acc: 0.1667
# Train F1: 0.0994 | Validation F1: 0.0640
#
# Epoch 15/30
# Train Loss: 1.7642 | Validation Loss: 1.7773
# Train Acc: 0.1905 | Validation Acc: 0.1667
# Train F1: 0.0989 | Validation F1: 0.0640
#
# Epoch 16/30
# Train Loss: 1.7624 | Validation Loss: 1.7777
# Train Acc: 0.1881 | Validation Acc: 0.1778
# Train F1: 0.0861 | Validation F1: 0.0664
#
# Epoch 17/30
# Train Loss: 1.7592 | Validation Loss: 1.7778
# Train Acc: 0.1929 | Validation Acc: 0.1778
# Train F1: 0.0917 | Validation F1: 0.0664
#
# Epoch 18/30
# Train Loss: 1.7567 | Validation Loss: 1.7738
# Train Acc: 0.2000 | Validation Acc: 0.1333
# Train F1: 0.1486 | Validation F1: 0.1016
#
# Epoch 19/30
# Train Loss: 1.7550 | Validation Loss: 1.7706
# Train Acc: 0.2190 | Validation Acc: 0.1778
# Train F1: 0.1662 | Validation F1: 0.0917
#
# Epoch 20/30
# Train Loss: 1.7467 | Validation Loss: 1.7697
# Train Acc: 0.2357 | Validation Acc: 0.1444
# Train F1: 0.1748 | Validation F1: 0.0944
#
# Epoch 21/30
# Train Loss: 1.7415 | Validation Loss: 1.7651
# Train Acc: 0.2571 | Validation Acc: 0.1556
# Train F1: 0.2132 | Validation F1: 0.1010
#
# Epoch 22/30
# Train Loss: 1.7247 | Validation Loss: 1.7630
# Train Acc: 0.2643 | Validation Acc: 0.2111
# Train F1: 0.2209 | Validation F1: 0.1557
#
# Epoch 23/30
# Train Loss: 1.7165 | Validation Loss: 1.7651
# Train Acc: 0.2643 | Validation Acc: 0.2222
# Train F1: 0.2048 | Validation F1: 0.1533
#
# Epoch 24/30
# Train Loss: 1.7085 | Validation Loss: 1.7627
# Train Acc: 0.2452 | Validation Acc: 0.2111
# Train F1: 0.1682 | Validation F1: 0.1686
#
# Epoch 25/30
# Train Loss: 1.7067 | Validation Loss: 1.7641
# Train Acc: 0.2262 | Validation Acc: 0.1667
# Train F1: 0.1649 | Validation F1: 0.1085
#
# Epoch 26/30
# Train Loss: 1.7007 | Validation Loss: 1.7618
# Train Acc: 0.2524 | Validation Acc: 0.2333
# Train F1: 0.1846 | Validation F1: 0.1803
#
# Epoch 27/30
# Train Loss: 1.6877 | Validation Loss: 1.7625
# Train Acc: 0.2595 | Validation Acc: 0.2222
# Train F1: 0.1898 | Validation F1: 0.1514
#
# Epoch 28/30
# Train Loss: 1.6946 | Validation Loss: 1.7632
# Train Acc: 0.2524 | Validation Acc: 0.2222
# Train F1: 0.1866 | Validation F1: 0.1526
#
# Epoch 29/30
# Train Loss: 1.6942 | Validation Loss: 1.7632
# Train Acc: 0.2548 | Validation Acc: 0.2222
# Train F1: 0.1891 | Validation F1: 0.1526
#
# Epoch 30/30
# Train Loss: 1.6934 | Validation Loss: 1.7632
# Train Acc: 0.2619 | Validation Acc: 0.2222
# Train F1: 0.1889 | Validation F1: 0.1526

# %%
plot_metrics(metrics, experiment_name)
create_metrics_table(metrics, experiment_name)
# Out:
# <style type="text/css">
# #T_734f9_row0_col0, #T_734f9_row0_col3, #T_734f9_row0_col6, #T_734f9_row1_col6, #T_734f9_row3_col6, #T_734f9_row4_col6, #T_734f9_row5_col6, #T_734f9_row6_col6, #T_734f9_row7_col5, #T_734f9_row7_col6, #T_734f9_row17_col4, #T_734f9_row25_col2, #T_734f9_row26_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_734f9_row0_col1, #T_734f9_row0_col2, #T_734f9_row1_col2, #T_734f9_row21_col3, #T_734f9_row21_col5, #T_734f9_row22_col3, #T_734f9_row25_col4, #T_734f9_row25_col6, #T_734f9_row29_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_734f9_row0_col4, #T_734f9_row1_col4, #T_734f9_row2_col4, #T_734f9_row3_col4, #T_734f9_row4_col4, #T_734f9_row5_col4, #T_734f9_row6_col4, #T_734f9_row7_col4, #T_734f9_row10_col4, #T_734f9_row11_col4, #T_734f9_row12_col4, #T_734f9_row13_col4, #T_734f9_row14_col4, #T_734f9_row24_col4 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_734f9_row0_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_734f9_row1_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_734f9_row1_col1, #T_734f9_row2_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_734f9_row1_col3, #T_734f9_row11_col5, #T_734f9_row12_col5 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_734f9_row1_col5 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_734f9_row2_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_734f9_row2_col2, #T_734f9_row3_col1, #T_734f9_row4_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_734f9_row2_col3, #T_734f9_row11_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_734f9_row2_col5 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_734f9_row2_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T